# %% [markdown]
# ## Ranks and topics: hSBM results on protein families

# %%
import pandas as pd
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
import tqdm as tqdm
import seaborn as sns
from bisect import bisect_left, bisect_right
from collections import defaultdict
import os
import sys
import networkx as nx

# %%
taxid_to_name_path = '../taxonomy_ncbi/taxid_to_name.tsv'
taxid_to_parent_path = '../taxonomy_ncbi/taxid_to_parent.names.ranks.tsv'

tid2nm = {}
with open(taxid_to_name_path, 'r') as f:
	for line in f:
		tid, name = line.strip().split('\t')
		tid2nm[int(tid)] = name
                
nm2tid = {v: k for k, v in tid2nm.items()}

# %% [markdown]
# ________________

# %% [markdown]
# ### Count matrix

# %%
countmatrix_path = '../uniprotkb_reference_proteomes/big_bacteria_countmatrix.csv'
df_cm = pd.read_csv(countmatrix_path, index_col=0)
df_cm
# Out:
#                      PF00002  PF00004  PF00005  PF00006  PF00008  PF00009  \
# species
# UP000000212_1234679        0        6       95        5        0        9
# UP000000231_312153         0        8       30        3        0        7
# UP000000233_379731         0       13       58        4        0        9
# UP000000235_369723         0        9       96        3        0        8
# UP000000238_349521         0       13       91        9        0        9
# ...                      ...      ...      ...      ...      ...      ...
# UP001268683_1456591        0        0        0        0        0        0
# UP001288380_3079793        0        0        0        0        0        0
# UP001289135_1332059        0        0        0        0        0        0
# UP001296776_85075          0        0        0        0        0        0
# UP001296967_49447          0        0        0        0        0        0
#
#                      PF00010  PF00011  PF00012  PF00013  ...  PF25791  \
# species                                                  ...
# UP000000212_1234679        0        0        2        2  ...        0
# UP000000231_312153         0        0        2        1  ...        0
# UP000000233_379731         0        2        3        1  ...        0
# UP000000235_369723         0        1        2        2  ...        0
# UP000000238_349521         0        2        5        1  ...        0
# ...                      ...      ...      ...      ...  ...      ...
# UP001268683_1456591        0        0        0        0  ...        0
# UP001288380_3079793        0        0        0        0  ...        0
# UP001289135_1332059        0        0        0        0  ...        0
# UP001296776_85075          0        0        0        0  ...        0
# UP001296967_49447          0        0        0        0  ...        0
#
#                      PF25792  PF25794  PF25796  PF25799  PF25800  PF25815  \
# species
# UP000000212_1234679        0        0        0        0        0        0
# UP000000231_312153         0        0        0        0        1        0
# UP000000233_379731         0        0        0        0        2        0
# UP000000235_369723         0        0        0        0        0        0
# UP000000238_349521         0        0        0        0        1        0
# ...                      ...      ...      ...      ...      ...      ...
# UP001268683_1456591        0        0        0        0        0        0
# UP001288380_3079793        0        0        0        0        0        0
# UP001289135_1332059        0        0        0        0        0        0
# UP001296776_85075          0        0        0        0        0        0
# UP001296967_49447          0        0        0        0        0        0
#
#                      PF25816  PF25818  PF25819
# species
# UP000000212_1234679        0        0        0
# UP000000231_312153         0        0        0
# UP000000233_379731         0        0        0
# UP000000235_369723         0        0        0
# UP000000238_349521         0        0        0
# ...                      ...      ...      ...
# UP001268683_1456591        0        0        0
# UP001288380_3079793        0        0        0
# UP001289135_1332059        0        0        0
# UP001296776_85075          0        0        0
# UP001296967_49447          0        0        0
#
# [9098 rows x 14693 columns]

# %%
idx = [x.split('_')[1] for x in df_cm.index]
df_cm.index = idx
df_cm
# Out:
#          PF00002  PF00004  PF00005  PF00006  PF00008  PF00009  PF00010  \
# 1234679        0        6       95        5        0        9        0
# 312153         0        8       30        3        0        7        0
# 379731         0       13       58        4        0        9        0
# 369723         0        9       96        3        0        8        0
# 349521         0       13       91        9        0        9        0
# ...          ...      ...      ...      ...      ...      ...      ...
# 1456591        0        0        0        0        0        0        0
# 3079793        0        0        0        0        0        0        0
# 1332059        0        0        0        0        0        0        0
# 85075          0        0        0        0        0        0        0
# 49447          0        0        0        0        0        0        0
#
#          PF00011  PF00012  PF00013  ...  PF25791  PF25792  PF25794  PF25796  \
# 1234679        0        2        2  ...        0        0        0        0
# 312153         0        2        1  ...        0        0        0        0
# 379731         2        3        1  ...        0        0        0        0
# 369723         1        2        2  ...        0        0        0        0
# 349521         2        5        1  ...        0        0        0        0
# ...          ...      ...      ...  ...      ...      ...      ...      ...
# 1456591        0        0        0  ...        0        0        0        0
# 3079793        0        0        0  ...        0        0        0        0
# 1332059        0        0        0  ...        0        0        0        0
# 85075          0        0        0  ...        0        0        0        0
# 49447          0        0        0  ...        0        0        0        0
#
#          PF25799  PF25800  PF25815  PF25816  PF25818  PF25819
# 1234679        0        0        0        0        0        0
# 312153         0        1        0        0        0        0
# 379731         0        2        0        0        0        0
# 369723         0        0        0        0        0        0
# 349521         0        1        0        0        0        0
# ...          ...      ...      ...      ...      ...      ...
# 1456591        0        0        0        0        0        0
# 3079793        0        0        0        0        0        0
# 1332059        0        0        0        0        0        0
# 85075          0        0        0        0        0        0
# 49447          0        0        0        0        0        0
#
# [9098 rows x 14693 columns]

# %% [markdown]
# _____________

# %%
tree = nx.Graph()
tree_dir = nx.DiGraph()

with open(taxid_to_parent_path, 'r') as f:
    for line in f:
        node_tid, node_rank, node_name, parent_tid, parent_rank, parent_name = line.rstrip('\n').split('\t')

        # normalize ids (keep as strings or cast to int consistently)
        node_tid = int(node_tid)
        parent_tid = int(parent_tid)

        # add nodes with attributes
        tree.add_node(node_tid, name=node_name.strip(), rank=node_rank.strip())
        tree_dir.add_node(node_tid, name=node_name.strip(), rank=node_rank.strip())
        tree.add_node(parent_tid, name=parent_name.strip(), rank=parent_rank.strip())
        tree_dir.add_node(parent_tid, name=parent_name.strip(), rank=parent_rank.strip())

        # parent -> child
        tree.add_edge(parent_tid, node_tid)
        tree_dir.add_edge(parent_tid, node_tid)

tree.remove_edge(1, 1)
tree_dir.remove_edge(1, 1)

print(f'Number of connected components in the tree: {nx.number_connected_components(tree)}')
print(f'Number of weakly connected components in the directed tree: {nx.number_weakly_connected_components(tree_dir)}')

print(f'Number of nodes in the tree: {tree.number_of_nodes()}')
print(f'Number of edges in the tree: {tree.number_of_edges()}')
# Out:
# Number of connected components in the tree: 1
# Number of weakly connected components in the directed tree: 1
# Number of nodes in the tree: 2703951
# Number of edges in the tree: 2703950

# %% [markdown]
# ### hSBM results

# %%
lvl = 0
clusters_path = f'./results/topsbm_level_{str(lvl)}_clusters.csv'

# %%
clusters_df = pd.read_csv(clusters_path)
n_clusters = clusters_df.shape[1]
print(f'Number of clusters at level {lvl}: {n_clusters}')
# Out:
# Number of clusters at level 0: 48

# %%
clusters_df
# Out:
#              Cluster 1            Cluster 2            Cluster 3  \
# 0   UP000001136_367737   UP000000813_176299   UP000014118_397291
# 1   UP000002495_235279   UP000002040_137722   UP000003438_411471
# 2   UP000002043_638303  UP000005258_1110502  UP000014129_1235835
# 3   UP000005981_392423  UP000018524_1287292  UP000014134_1235800
# 4   UP000007803_563040      UP000001054_394   UP000014150_397290
# ..                 ...                  ...                  ...
# 73                 NaN                  NaN                  NaN
# 74                 NaN                  NaN                  NaN
# 75                 NaN                  NaN                  NaN
# 76                 NaN                  NaN                  NaN
# 77                 NaN                  NaN                  NaN
#
#              Cluster 4            Cluster 5            Cluster 6  \
# 0   UP000001115_316278  UP000016648_1115809   UP000007809_675635
# 1    UP000001961_64471   UP000006657_709991   UP000004245_525370
# 2    UP000000788_93059   UP000004295_553175    UP000001584_83332
# 3   UP000010379_195253   UP000004394_862515   UP000001419_233413
# 4   UP000001420_167539   UP000006545_879243  UP000005143_1097667
# ..                 ...                  ...                  ...
# 73                 NaN                  NaN                  NaN
# 74                 NaN                  NaN                  NaN
# 75                 NaN                  NaN                  NaN
# 76                 NaN                  NaN                  NaN
# 77                 NaN                  NaN                  NaN
#
#               Cluster 7           Cluster 8            Cluster 9  \
# 0    UP000008871_393595  UP000000640_196162  UP000012063_1293054
# 1    UP000014568_421052  UP000003868_312284   UP000006427_469381
# 2   UP000003511_1055526  UP000008229_469383   UP000006804_688269
# 3    UP000001231_523791  UP000001116_266940   UP000006866_572479
# 4    UP000007477_871585  UP000008221_351607   UP000005096_584708
# ..                  ...                 ...                  ...
# 73                  NaN                 NaN                  NaN
# 74                  NaN                 NaN                  NaN
# 75                  NaN                 NaN                  NaN
# 76                  NaN                 NaN                  NaN
# 77                  NaN                 NaN                  NaN
#
#              Cluster 10  ...           Cluster 39           Cluster 40  \
# 0    UP000004263_207949  ...   UP000001902_591001   UP000003195_706434
# 1    UP000006286_930169  ...  UP000016640_1321779  UP000010802_1209989
# 2    UP000006282_385025  ...   UP000007093_568816   UP000003277_742743
# 3   UP000017838_1408164  ...   UP000003503_888062   UP000000272_555079
# 4     UP000002677_83406  ...   UP000002072_519441   UP000010880_748449
# ..                  ...  ...                  ...                  ...
# 73                  NaN  ...                  NaN                  NaN
# 74                  NaN  ...                  NaN                  NaN
# 75                  NaN  ...                  NaN                  NaN
# 76                  NaN  ...                  NaN                  NaN
# 77                  NaN  ...                  NaN                  NaN
#
#             Cluster 41           Cluster 42           Cluster 43  \
# 0   UP000005439_679936  UP000007332_1071400  UP000015503_1245471
# 1   UP000000323_525904  UP000007271_1185325  UP000017050_1203578
# 2   UP000004508_485913   UP000001285_714313   UP000002515_223283
# 3                  NaN  UP000001279_1069534   UP000001062_717774
# 4                  NaN   UP000001259_390333   UP000000233_379731
# ..                 ...                  ...                  ...
# 73                 NaN   UP000000432_220668                  NaN
# 74                 NaN   UP000005147_883112                  NaN
# 75                 NaN   UP000019050_592010                  NaN
# 76                 NaN   UP000005388_764291                  NaN
# 77                 NaN  UP000018559_1392007                  NaN
#
#             Cluster 44           Cluster 45          Cluster 46  \
# 0   UP000007113_682795  UP000014154_1235796  UP000005286_879305
# 1   UP000006844_401053   UP000012651_997872  UP000005984_525254
# 2   UP000019151_861299   UP000003056_443342  UP000003422_997350
# 3   UP000002432_204669   UP000005947_525256  UP000005244_796937
# 4   UP000002207_240015   UP000004830_742742  UP000003280_862517
# ..                 ...                  ...                 ...
# 73                 NaN                  NaN                 NaN
# 74                 NaN                  NaN                 NaN
# 75                 NaN                  NaN                 NaN
# 76                 NaN                  NaN                 NaN
# 77                 NaN                  NaN                 NaN
#
#             Cluster 47           Cluster 48
# 0   UP000002415_381764   UP000002480_272947
# 1   UP000004793_511051   UP000007794_291272
# 2   UP000006889_632518   UP000001174_177416
# 3   UP000002382_521045  UP000018554_1073362
# 4   UP000007719_515635  UP000004116_1005043
# ..                 ...                  ...
# 73                 NaN                  NaN
# 74                 NaN                  NaN
# 75                 NaN                  NaN
# 76                 NaN                  NaN
# 77                 NaN                  NaN
#
# [78 rows x 48 columns]

# %%
for col in clusters_df.columns:
    # populate cluster with taxid
    clusters_df[col] = clusters_df[col].apply(lambda x: int(x.split('_')[1]) if pd.notnull(x) else x)
    
clusters_df
# Out:
#     Cluster 1  Cluster 2  Cluster 3  Cluster 4  Cluster 5  Cluster 6  \
# 0    367737.0   176299.0   397291.0   316278.0  1115809.0   675635.0
# 1    235279.0   137722.0   411471.0    64471.0   709991.0   525370.0
# 2    638303.0  1110502.0  1235835.0    93059.0   553175.0    83332.0
# 3    392423.0  1287292.0  1235800.0   195253.0   862515.0   233413.0
# 4    563040.0      394.0   397290.0   167539.0   879243.0  1097667.0
# ..        ...        ...        ...        ...        ...        ...
# 73        NaN        NaN        NaN        NaN        NaN        NaN
# 74        NaN        NaN        NaN        NaN        NaN        NaN
# 75        NaN        NaN        NaN        NaN        NaN        NaN
# 76        NaN        NaN        NaN        NaN        NaN        NaN
# 77        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Cluster 7  Cluster 8  Cluster 9  Cluster 10  ...  Cluster 39  Cluster 40  \
# 0    393595.0   196162.0  1293054.0    207949.0  ...    591001.0    706434.0
# 1    421052.0   312284.0   469381.0    930169.0  ...   1321779.0   1209989.0
# 2   1055526.0   469383.0   688269.0    385025.0  ...    568816.0    742743.0
# 3    523791.0   266940.0   572479.0   1408164.0  ...    888062.0    555079.0
# 4    871585.0   351607.0   584708.0     83406.0  ...    519441.0    748449.0
# ..        ...        ...        ...         ...  ...         ...         ...
# 73        NaN        NaN        NaN         NaN  ...         NaN         NaN
# 74        NaN        NaN        NaN         NaN  ...         NaN         NaN
# 75        NaN        NaN        NaN         NaN  ...         NaN         NaN
# 76        NaN        NaN        NaN         NaN  ...         NaN         NaN
# 77        NaN        NaN        NaN         NaN  ...         NaN         NaN
#
#     Cluster 41  Cluster 42  Cluster 43  Cluster 44  Cluster 45  Cluster 46  \
# 0     679936.0     1071400   1245471.0    682795.0   1235796.0    879305.0
# 1     525904.0     1185325   1203578.0    401053.0    997872.0    525254.0
# 2     485913.0      714313    223283.0    861299.0    443342.0    997350.0
# 3          NaN     1069534    717774.0    204669.0    525256.0    796937.0
# 4          NaN      390333    379731.0    240015.0    742742.0    862517.0
# ..         ...         ...         ...         ...         ...         ...
# 73         NaN      220668         NaN         NaN         NaN         NaN
# 74         NaN      883112         NaN         NaN         NaN         NaN
# 75         NaN      592010         NaN         NaN         NaN         NaN
# 76         NaN      764291         NaN         NaN         NaN         NaN
# 77         NaN     1392007         NaN         NaN         NaN         NaN
#
#     Cluster 47  Cluster 48
# 0     381764.0    272947.0
# 1     511051.0    291272.0
# 2     632518.0    177416.0
# 3     521045.0   1073362.0
# 4     515635.0   1005043.0
# ..         ...         ...
# 73         NaN         NaN
# 74         NaN         NaN
# 75         NaN         NaN
# 76         NaN         NaN
# 77         NaN         NaN
#
# [78 rows x 48 columns]

# %%
clusters = {}
for i in range(n_clusters):
    clusters[i] = clusters_df.iloc[:, i].dropna().tolist()

# %% [markdown]
# ________________________________

# %%
def mrca(tree_dir: nx.DiGraph, nodes, *, verbose=True):
    # --- normalize labels like 795666.0 -> 795666
    def _normalize(u):
        if isinstance(u, float) and u.is_integer():
            return int(u)
        return u

    nodes = [ _normalize(u) for u in nodes ]
    if not nodes:
        return None

    # Build parent map + find root (assumes arborescence)
    parent = {}
    root = None
    for v in tree_dir.nodes:
        preds = list(tree_dir.predecessors(v))
        if len(preds) > 1:
            raise ValueError(f"Graph is not a tree (node {v} has >1 parent)")
        parent[v] = preds[0] if preds else None
        if not preds:
            root = v
    if root is None:
        raise ValueError("No root found (cycle or no in-degree-0 node)")

    # Depth from root (BFS)
    depth = {root: 0}
    q = deque([root])
    while q:
        a = q.popleft()
        for b in tree_dir.successors(a):
            depth[b] = depth[a] + 1
            q.append(b)

    # Keep only nodes present in this tree
    present = [u for u in nodes if u in parent]
    skipped = len(nodes) - len(present)
    if verbose and skipped:
        print(f"[mrca] Skipping {skipped} node(s) not in the tree.")

    if len(present) < 2:
        return None

    # Ancestor set (including self); empty if node somehow missing
    def anc_set(u):
        s = set()
        while u is not None and u in parent:
            s.add(u)
            u = parent[u]
        return s

    # Intersect ancestor sets
    common = anc_set(present[0])
    for u in present[1:]:
        common &= anc_set(u)
        if not common:
            return None  # different components or no shared ancestor in this tree

    # Deepest common ancestor
    return max(common, key=lambda x: depth.get(x, -1))

def tip_descendants(tree_dir, node):
    tips = set()
    q = deque([node])
    while q:
        u = q.popleft()
        children = list(tree_dir.successors(u))
        if not children:
            tips.add(u)
        else:
            q.extend(children)
    return tips

def cluster_clade_stats(tree_dir, C):
	
	C = set(C)
	
	print(f'\tComputing MRCA...')
	r = mrca(tree_dir, C)
    
	if r is None:
		print(f'\tNo MRCA found!')
		return dict(size=len(C), precision=0.0, recall=0.0, F1=0.0, clade_like=False)

	print(f'\tMRCA found: {r}. Computing descendants...')
	D = tip_descendants(tree_dir, r)
	inter = len(C & D)
	print(f'\tCluster size: {len(C)}. MRCA descendants size: {len(D)}. Intersection size: {inter}.')
	
	if inter == 0:
		print(f'\tNo intersection between cluster and descendants of MRCA!')
		return dict(size=len(C), precision=0.0, recall=0.0, F1=0.0, clade_like=False)
	
	print(f'\tComputing precision, recall, F1...')
	precision = inter / len(D)
	recall = inter / len(C)
	F1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0.0
	
	return dict(size=len(C), precision=precision, recall=recall, F1=F1,
                clade_like=(precision == 1.0 and recall == 1.0), mrca=r, mrca_size=len(D))


cluster_stats = {}
for i in range(n_clusters):
	print(f'Processing cluster {i+1}/{n_clusters} ...')
	cluster_stats[i] = cluster_clade_stats(tree_dir, clusters[i])
# Out:
# Processing cluster 1/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 42. MRCA descendants size: 278020. Intersection size: 41.
# 	Computing precision, recall, F1...
# Processing cluster 2/48 ...
# 	Computing MRCA...
# 	MRCA found: 28211. Computing descendants...
# 	Cluster size: 31. MRCA descendants size: 68707. Intersection size: 31.
# 	Computing precision, recall, F1...
# Processing cluster 3/48 ...
# 	Computing MRCA...
# 	MRCA found: 1239. Computing descendants...
# 	Cluster size: 40. MRCA descendants size: 90689. Intersection size: 40.
# 	Computing precision, recall, F1...
# Processing cluster 4/48 ...
# 	Computing MRCA...
# 	MRCA found: 3028117. Computing descendants...
# 	Cluster size: 22. MRCA descendants size: 31831. Intersection size: 22.
# 	Computing precision, recall, F1...
# Processing cluster 5/48 ...
# 	Computing MRCA...
# 	MRCA found: 976. Computing descendants...
# 	Cluster size: 52. MRCA descendants size: 23910. Intersection size: 52.
# 	Computing precision, recall, F1...
# Processing cluster 6/48 ...
# 	Computing MRCA...
# 	MRCA found: 201174. Computing descendants...
# 	Cluster size: 35. MRCA descendants size: 93547. Intersection size: 34.
# 	Computing precision, recall, F1...
# Processing cluster 7/48 ...
# 	Computing MRCA...
# 	MRCA found: 1224. Computing descendants...
# 	Cluster size: 13. MRCA descendants size: 234365. Intersection size: 13.
# 	Computing precision, recall, F1...
# Processing cluster 8/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 39. MRCA descendants size: 569721. Intersection size: 39.
# 	Computing precision, recall, F1...
# Processing cluster 9/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 13. MRCA descendants size: 569721. Intersection size: 13.
# 	Computing precision, recall, F1...
# Processing cluster 10/48 ...
# 	Computing MRCA...
# 	MRCA found: 1224. Computing descendants...
# 	Cluster size: 20. MRCA descendants size: 234365. Intersection size: 20.
# 	Computing precision, recall, F1...
# Processing cluster 11/48 ...
# 	Computing MRCA...
# 	MRCA found: 186801. Computing descendants...
# 	Cluster size: 13. MRCA descendants size: 11445. Intersection size: 13.
# 	Computing precision, recall, F1...
# Processing cluster 12/48 ...
# 	Computing MRCA...
# 	MRCA found: 1224. Computing descendants...
# 	Cluster size: 46. MRCA descendants size: 234365. Intersection size: 46.
# 	Computing precision, recall, F1...
# Processing cluster 13/48 ...
# 	Computing MRCA...
# 	MRCA found: 1224. Computing descendants...
# 	Cluster size: 34. MRCA descendants size: 234365. Intersection size: 34.
# 	Computing precision, recall, F1...
# Processing cluster 14/48 ...
# 	Computing MRCA...
# 	MRCA found: 1236. Computing descendants...
# 	Cluster size: 40. MRCA descendants size: 134380. Intersection size: 39.
# 	Computing precision, recall, F1...
# Processing cluster 15/48 ...
# 	Computing MRCA...
# 	MRCA found: 1385. Computing descendants...
# 	Cluster size: 12. MRCA descendants size: 61959. Intersection size: 12.
# 	Computing precision, recall, F1...
# Processing cluster 16/48 ...
# 	Computing MRCA...
# 	MRCA found: 1760. Computing descendants...
# 	Cluster size: 48. MRCA descendants size: 91371. Intersection size: 47.
# 	Computing precision, recall, F1...
# Processing cluster 17/48 ...
# 	Computing MRCA...
# 	MRCA found: 68336. Computing descendants...
# 	Cluster size: 72. MRCA descendants size: 24583. Intersection size: 72.
# 	Computing precision, recall, F1...
# Processing cluster 18/48 ...
# 	Computing MRCA...
# 	MRCA found: 1239. Computing descendants...
# 	Cluster size: 42. MRCA descendants size: 90689. Intersection size: 39.
# 	Computing precision, recall, F1...
# Processing cluster 19/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 29. MRCA descendants size: 569721. Intersection size: 29.
# 	Computing precision, recall, F1...
# Processing cluster 20/48 ...
# 	Computing MRCA...
# [mrca] Skipping 1 node(s) not in the tree.
# 	MRCA found: 80840. Computing descendants...
# 	Cluster size: 24. MRCA descendants size: 23352. Intersection size: 23.
# 	Computing precision, recall, F1...
# Processing cluster 21/48 ...
# 	Computing MRCA...
# 	MRCA found: 3028117. Computing descendants...
# 	Cluster size: 39. MRCA descendants size: 31831. Intersection size: 39.
# 	Computing precision, recall, F1...
# Processing cluster 22/48 ...
# 	Computing MRCA...
# 	MRCA found: 2818505. Computing descendants...
# 	Cluster size: 4. MRCA descendants size: 932. Intersection size: 4.
# 	Computing precision, recall, F1...
# Processing cluster 23/48 ...
# 	Computing MRCA...
# 	MRCA found: 28211. Computing descendants...
# 	Cluster size: 45. MRCA descendants size: 68707. Intersection size: 45.
# 	Computing precision, recall, F1...
# Processing cluster 24/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783257. Computing descendants...
# 	Cluster size: 10. MRCA descendants size: 3924. Intersection size: 10.
# 	Computing precision, recall, F1...
# Processing cluster 25/48 ...
# 	Computing MRCA...
# 	MRCA found: 544448. Computing descendants...
# 	Cluster size: 36. MRCA descendants size: 3928. Intersection size: 35.
# 	Computing precision, recall, F1...
# Processing cluster 26/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 18. MRCA descendants size: 278020. Intersection size: 17.
# 	Computing precision, recall, F1...
# Processing cluster 27/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 11. MRCA descendants size: 569721. Intersection size: 11.
# 	Computing precision, recall, F1...
# Processing cluster 28/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 48. MRCA descendants size: 569721. Intersection size: 47.
# 	Computing precision, recall, F1...
# Processing cluster 29/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 14. MRCA descendants size: 278020. Intersection size: 14.
# 	Computing precision, recall, F1...
# Processing cluster 30/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 7. MRCA descendants size: 278020. Intersection size: 7.
# 	Computing precision, recall, F1...
# Processing cluster 31/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783272. Computing descendants...
# 	Cluster size: 35. MRCA descendants size: 223458. Intersection size: 35.
# 	Computing precision, recall, F1...
# Processing cluster 32/48 ...
# 	Computing MRCA...
# 	MRCA found: 28211. Computing descendants...
# 	Cluster size: 27. MRCA descendants size: 68707. Intersection size: 26.
# 	Computing precision, recall, F1...
# Processing cluster 33/48 ...
# 	Computing MRCA...
# 	MRCA found: 203692. Computing descendants...
# 	Cluster size: 20. MRCA descendants size: 3487. Intersection size: 20.
# 	Computing precision, recall, F1...
# Processing cluster 34/48 ...
# 	Computing MRCA...
# 	MRCA found: 91347. Computing descendants...
# 	Cluster size: 40. MRCA descendants size: 39072. Intersection size: 32.
# 	Computing precision, recall, F1...
# Processing cluster 35/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783272. Computing descendants...
# 	Cluster size: 32. MRCA descendants size: 223458. Intersection size: 30.
# 	Computing precision, recall, F1...
# Processing cluster 36/48 ...
# 	Computing MRCA...
# 	MRCA found: 1760. Computing descendants...
# 	Cluster size: 57. MRCA descendants size: 91371. Intersection size: 57.
# 	Computing precision, recall, F1...
# Processing cluster 37/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 15. MRCA descendants size: 569721. Intersection size: 15.
# 	Computing precision, recall, F1...
# Processing cluster 38/48 ...
# 	Computing MRCA...
# 	MRCA found: 28211. Computing descendants...
# 	Cluster size: 27. MRCA descendants size: 68707. Intersection size: 27.
# 	Computing precision, recall, F1...
# Processing cluster 39/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 19. MRCA descendants size: 569721. Intersection size: 19.
# 	Computing precision, recall, F1...
# Processing cluster 40/48 ...
# 	Computing MRCA...
# 	MRCA found: 1239. Computing descendants...
# 	Cluster size: 16. MRCA descendants size: 90689. Intersection size: 16.
# 	Computing precision, recall, F1...
# Processing cluster 41/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783272. Computing descendants...
# 	Cluster size: 3. MRCA descendants size: 223458. Intersection size: 3.
# 	Computing precision, recall, F1...
# Processing cluster 42/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783272. Computing descendants...
# 	Cluster size: 78. MRCA descendants size: 223458. Intersection size: 75.
# 	Computing precision, recall, F1...
# Processing cluster 43/48 ...
# 	Computing MRCA...
# 	MRCA found: 1224. Computing descendants...
# 	Cluster size: 12. MRCA descendants size: 234365. Intersection size: 11.
# 	Computing precision, recall, F1...
# Processing cluster 44/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 8. MRCA descendants size: 278020. Intersection size: 8.
# 	Computing precision, recall, F1...
# Processing cluster 45/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 21. MRCA descendants size: 569721. Intersection size: 21.
# 	Computing precision, recall, F1...
# Processing cluster 46/48 ...
# 	Computing MRCA...
# 	MRCA found: 1783272. Computing descendants...
# 	Cluster size: 28. MRCA descendants size: 223458. Intersection size: 28.
# 	Computing precision, recall, F1...
# Processing cluster 47/48 ...
# 	Computing MRCA...
# 	MRCA found: 2. Computing descendants...
# 	Cluster size: 11. MRCA descendants size: 569721. Intersection size: 11.
# 	Computing precision, recall, F1...
# Processing cluster 48/48 ...
# 	Computing MRCA...
# 	MRCA found: 3379134. Computing descendants...
# 	Cluster size: 54. MRCA descendants size: 278020. Intersection size: 50.
# 	Computing precision, recall, F1...

# %%
cluster_stats_df = pd.DataFrame.from_dict(cluster_stats, orient='index')
cluster_stats_df
cluster_stats_df['mrca_name'] = cluster_stats_df['mrca'].apply(lambda x: tid2nm[x] if x in tid2nm else 'unknown')

# %%
cluster_stats_df
# Out:
#     size  precision    recall        F1  clade_like     mrca  mrca_size  \
# 0     42   0.000147  0.976190  0.000295       False  3379134     278020
# 1     31   0.000451  1.000000  0.000902       False    28211      68707
# 2     40   0.000441  1.000000  0.000882       False     1239      90689
# 3     22   0.000691  1.000000  0.001381       False  3028117      31831
# 4     52   0.002175  1.000000  0.004340       False      976      23910
# 5     35   0.000363  0.971429  0.000727       False   201174      93547
# 6     13   0.000055  1.000000  0.000111       False     1224     234365
# 7     39   0.000068  1.000000  0.000137       False        2     569721
# 8     13   0.000023  1.000000  0.000046       False        2     569721
# 9     20   0.000085  1.000000  0.000171       False     1224     234365
# 10    13   0.001136  1.000000  0.002269       False   186801      11445
# 11    46   0.000196  1.000000  0.000392       False     1224     234365
# 12    34   0.000145  1.000000  0.000290       False     1224     234365
# 13    40   0.000290  0.975000  0.000580       False     1236     134380
# 14    12   0.000194  1.000000  0.000387       False     1385      61959
# 15    48   0.000514  0.979167  0.001028       False     1760      91371
# 16    72   0.002929  1.000000  0.005841       False    68336      24583
# 17    42   0.000430  0.928571  0.000860       False     1239      90689
# 18    29   0.000051  1.000000  0.000102       False        2     569721
# 19    24   0.000985  0.958333  0.001968       False    80840      23352
# 20    39   0.001225  1.000000  0.002447       False  3028117      31831
# 21     4   0.004292  1.000000  0.008547       False  2818505        932
# 22    45   0.000655  1.000000  0.001309       False    28211      68707
# 23    10   0.002548  1.000000  0.005084       False  1783257       3924
# 24    36   0.008910  0.972222  0.017659       False   544448       3928
# 25    18   0.000061  0.944444  0.000122       False  3379134     278020
# 26    11   0.000019  1.000000  0.000039       False        2     569721
# 27    48   0.000082  0.979167  0.000165       False        2     569721
# 28    14   0.000050  1.000000  0.000101       False  3379134     278020
# 29     7   0.000025  1.000000  0.000050       False  3379134     278020
# 30    35   0.000157  1.000000  0.000313       False  1783272     223458
# 31    27   0.000378  0.962963  0.000757       False    28211      68707
# 32    20   0.005736  1.000000  0.011406       False   203692       3487
# 33    40   0.000819  0.800000  0.001636       False    91347      39072
# 34    32   0.000134  0.937500  0.000268       False  1783272     223458
# 35    57   0.000624  1.000000  0.001247       False     1760      91371
# 36    15   0.000026  1.000000  0.000053       False        2     569721
# 37    27   0.000393  1.000000  0.000786       False    28211      68707
# 38    19   0.000033  1.000000  0.000067       False        2     569721
# 39    16   0.000176  1.000000  0.000353       False     1239      90689
# 40     3   0.000013  1.000000  0.000027       False  1783272     223458
# 41    78   0.000336  0.961538  0.000671       False  1783272     223458
# 42    12   0.000047  0.916667  0.000094       False     1224     234365
# 43     8   0.000029  1.000000  0.000058       False  3379134     278020
# 44    21   0.000037  1.000000  0.000074       False        2     569721
# 45    28   0.000125  1.000000  0.000251       False  1783272     223458
# 46    11   0.000019  1.000000  0.000039       False        2     569721
# 47    54   0.000180  0.925926  0.000360       False  3379134     278020
#
#                          mrca_name
# 0                   Pseudomonadati
# 1              Alphaproteobacteria
# 2                        Bacillota
# 3                     Cyanophyceae
# 4                     Bacteroidota
# 5                   Actinomycetota
# 6                   Pseudomonadota
# 7                         Bacteria
# 8                         Bacteria
# 9                   Pseudomonadota
# 10                      Clostridia
# 11                  Pseudomonadota
# 12                  Pseudomonadota
# 13             Gammaproteobacteria
# 14                      Bacillales
# 15                   Actinomycetes
# 16  Bacteroidota/Chlorobiota group
# 17                       Bacillota
# 18                        Bacteria
# 19                 Burkholderiales
# 20                    Cyanophyceae
# 21                     Myxococcota
# 22             Alphaproteobacteria
# 23                       PVC group
# 24                  Mycoplasmatota
# 25                  Pseudomonadati
# 26                        Bacteria
# 27                        Bacteria
# 28                  Pseudomonadati
# 29                  Pseudomonadati
# 30                       Bacillati
# 31             Alphaproteobacteria
# 32                    Spirochaetia
# 33                Enterobacterales
# 34                       Bacillati
# 35                   Actinomycetes
# 36                        Bacteria
# 37             Alphaproteobacteria
# 38                        Bacteria
# 39                       Bacillota
# 40                       Bacillati
# 41                       Bacillati
# 42                  Pseudomonadota
# 43                  Pseudomonadati
# 44                        Bacteria
# 45                       Bacillati
# 46                        Bacteria
# 47                  Pseudomonadati

# %%
clusters_names = {}
for i in range(n_clusters):
	clusters_names[i] = [tid2nm[tid] if tid in tid2nm else 'unknown' for tid in clusters[i]]

clusters_names
# Out:
# {0: ['Aliarcobacter butzleri RM4018',
#   'Helicobacter hepaticus ATCC 51449',
#   'Thermocrinis albus DSM 14484',
#   'Hydrogenivirga sp. 128-5-R1-1',
#   'Sulfurimonas autotrophica DSM 16294',
#   'Nitratiruptor sp. SB155-2',
#   'Helicobacter canis NCTC 12740',
#   'Helicobacter macacae MIT 99-5501',
#   'Sulfurimonas hongkongensis',
#   'Helicobacter canadensis MIT 98-5491',
#   'Helicobacter bilis ATCC 43879',
#   'Hippea maritima DSM 10411',
#   'Helicobacter fennelliae MRY12-0050',
#   'Arcobacter nitrofigilis DSM 7299',
#   'Desulfurobacterium thermolithotrophum DSM 11699',
#   'Sulfurimonas denitrificans DSM 1251',
#   'Sulfurovum sp. AR',
#   'Nitratifractor salsuginis DSM 16511',
#   'Campylobacter curvus 525.92',
#   'Mucispirillum schaedleri ASF457',
#   'Campylobacter jejuni subsp. jejuni NCTC 11168 = ATCC 700819',
#   'Aquifex aeolicus VF5',
#   'Sulfurimonas gotlandica GD1',
#   'Chitinivibrio alkaliphilus ACht1',
#   'Hydrogenobaculum sp. HO',
#   'Borreliella burgdorferi B31',
#   'Helicobacter bizzozeronii CIII-1',
#   'Thermodesulfobium narugense DSM 14796',
#   'Thermodesulfobacterium geofontis OPF15',
#   'Helicobacter mustelae 12198',
#   'Sulfurospirillum deleyianum DSM 6946',
#   'Borrelia duttonii CR2A',
#   'Helicobacter pylori 26695',
#   'Sulfurihydrogenibium azorense Az-Fu1',
#   'Thiovulum sp. ES',
#   'Lawsonia intracellularis PHE/MN1-00',
#   'Campylobacter hominis ATCC BAA-381',
#   'Persephonella marina EX-H1',
#   'Hydrogenobacter thermophilus TK-6',
#   'Sulfurihydrogenibium yellowstonense SS-5',
#   'Campylobacter gracilis RM3268',
#   'Campylobacter ureolyticus ACS-301-V-Sch3b'],
#  1: ['Agrobacterium fabrum str. C58',
#   'Azospirillum sp. B510',
#   'Tistrella mobilis KA081020-065',
#   'Mesorhizobium sp. LSHC420B00',
#   'Sinorhizobium fredii NGR234',
#   'Nitratireductor pacificus pht-3B',
#   'Rhizobium etli CFN 42',
#   'Methylobacterium nodulans ORS 2060',
#   'Bradyrhizobium diazoefficiens USDA 110',
#   'Pseudoroseomonas cervicalis ATCC 49957',
#   'Pelagibacterium halotolerans B2',
#   'Bradyrhizobium sp. ORS 278',
#   'Mesorhizobium australicum WSM2073',
#   'Bradyrhizobium sp. STM 3843',
#   'Acetobacteraceae bacterium AT-5844',
#   'Rhodopseudomonas palustris CGA009',
#   'Pseudorhizobium banfieldiae',
#   'Sinorhizobium meliloti 1021',
#   'Mesorhizobium alhagi CCNWXJ12-2',
#   'Afipia sp. P52-10',
#   'Azorhizobium caulinodans ORS 571',
#   'Mesorhizobium amorphae CCNWGS0123',
#   'Rhizobium mesoamericanum STM3625',
#   'Nitratireductor indicus C115',
#   'Brucella anthropi ATCC 49188',
#   'Afipia broomeae ATCC 49717',
#   'Rhizobium sp. PDO1-076',
#   'Brucella intermedia 229E',
#   'Phyllobacterium sp. YR531',
#   'Xanthobacter versatilis',
#   'Allorhizobium ampelinum S4'],
#  2: ['Lachnospiraceae bacterium A4',
#   'Subdoligranulum variabile DSM 15176',
#   'Anaerotruncus sp. G3(2012)',
#   'Lachnospiraceae bacterium 10-1',
#   'Lachnospiraceae bacterium A2',
#   'Eubacterium sp. 14-2',
#   'Lachnospiraceae bacterium 3-1',
#   'Mediterraneibacter gnavus CC55_001C',
#   'Lachnospiraceae bacterium 9_1_43BFAA',
#   'Pseudoflavonifractor capillosus ATCC 29799',
#   'Clostridium sp. D5',
#   'Oribacterium sinus F0268',
#   'Lachnospiraceae bacterium 1_4_56FAA',
#   'Firmicutes bacterium ASF500',
#   'Catonella morbi ATCC 51271',
#   'Lachnospiraceae bacterium 2_1_46FAA',
#   'Butyrivibrio proteoclasticus B316',
#   'butyrate-producing bacterium SM4/1',
#   'Faecalibacterium prausnitzii L2-6',
#   'Ruminococcaceae bacterium D16',
#   '[Clostridium] symbiosum WAL-14163',
#   'Clostridium sp. MD294',
#   'Eubacterium plexicaudatum ASF492',
#   'Roseburia hominis A2-183',
#   'Lachnospira eligens ATCC 27750',
#   'Lachnospiraceae bacterium MD308',
#   'Lachnospiraceae oral taxon 107 str. F0167',
#   'Lachnospiraceae bacterium 3_1_57FAA_CT1',
#   '[Clostridium] methylpentosum DSM 5476',
#   'Butyricicoccus pullicaecorum 1.2',
#   'Lachnospiraceae bacterium MD335',
#   'Lachnospiraceae bacterium M18-1',
#   'Oscillibacter sp. 1-3',
#   'Lachnospiraceae bacterium 28-4',
#   '[Ruminococcus] lactaris ATCC 29176',
#   'Lachnospiraceae bacterium 5_1_57FAA',
#   'Oribacterium parvum ACB1',
#   'Hungatella hathewayi WAL-18680',
#   '[Eubacterium] cellulosolvens 6',
#   'Marvinbryantia formatexigens DSM 14469'],
#  3: ['Synechococcus sp. RCC307',
#   'Synechococcus sp. CC9311',
#   'Prochlorococcus marinus str. MIT 9211',
#   'Synechococcus sp. PCC 6312',
#   'Prochlorococcus marinus subsp. marinus str. CCMP1375',
#   'Prochlorococcus marinus str. MIT 9313',
#   'Synechococcus sp. WH 7803',
#   'Rubidibacter lacunae KORDI 51-2',
#   'Cyanobacterium aponinum PCC 10605',
#   'Synechococcus sp. PCC 7502',
#   'Cyanobacterium stanieri PCC 7202',
#   'Thermosynechococcus vestitus BP-1',
#   "'Nostoc azollae' 0708",
#   'Prochlorococcus marinus str. MIT 9301',
#   'Prochlorococcus marinus str. NATL2A',
#   'Candidatus Atelocyanobacterium thalassa isolate ALOHA',
#   'Synechococcus sp. RS9916',
#   'Synechococcus sp. WH 5701',
#   'Picosynechococcus sp. PCC 7002',
#   'Cyanobium sp. PCC 7001',
#   "Synechococcus sp. JA-2-3B'a(2-13)",
#   'Synechocystis sp. PCC 6803 substr. Kazusa'],
#  4: ['Segatella baroniae F0067',
#   'Odoribacter splanchnicus DSM 20712',
#   'Porphyromonas endodontalis ATCC 35406',
#   'Hoylesella marshii DSM 16973 = JCM 13450',
#   'Porphyromonas asaccharolytica DSM 20707',
#   'Candidatus Azobacteroides pseudotrichonymphae genomovar. CFP2',
#   'Segatella baroniae B14',
#   'Prevotella bivia DSM 20514',
#   'Hallella multisaccharivorax DSM 17128',
#   'Bacteroides coprosuis DSM 18011',
#   'Prevotella histicola F0411',
#   'Bacteroides helcogenes P 36-108',
#   'Bacteroidetes oral taxon 274 str. F0058',
#   'Paludibacter propionicigenes WB4',
#   'Porphyromonas gingivalis W83',
#   'Phocaeicola massiliensis B84634 = Timone 84634 = DSM 17679 = JCM 13223',
#   'Alistipes shahii WAL 8301',
#   'Parabacteroides distasonis ATCC 8503',
#   'Prevotella dentalis DSM 3688',
#   'Dysgonomonas gadei ATCC BAA-286',
#   'Dysgonomonas mossii DSM 22836',
#   'Parabacteroides johnsonii CL02T12C29',
#   'Segatella oris C735',
#   'Alloprevotella tannerae ATCC 51259',
#   'Prevotella sp. oral taxon 317 str. F0108',
#   'Bacteroides thetaiotaomicron VPI-5482',
#   'Segatella salivae DSM 15606',
#   'Bacteroides fluxus YIT 12057',
#   'Bacteroidetes bacterium oral taxon 272 str. F0290',
#   'Bacteroides fragilis CL05T12C13',
#   'Prevotella veroralis F0319',
#   'Hoylesella pleuritidis F0068',
#   'Prevotella sp. oral taxon 299 str. F0039',
#   'Segatella maculosa OT 289',
#   'Hallella bergensis DSM 17361',
#   'Alloprevotella rava F0323',
#   'Prevotella micans F0438',
#   'Bacteroides sp. D2',
#   'Porphyromonas sp. oral taxon 279 str. F0450',
#   'Segatella buccae ATCC 33574',
#   'Xylanibacter ruminicola 23',
#   'Bacteroides nordii CL02T12C05',
#   'Hoylesella timonensis CRIS 5C-B1',
#   'Hoylesella oralis ATCC 33269',
#   'Alloprevotella sp. oral taxon 473 str. F0040',
#   'Segatella oulorum F0390',
#   'Alistipes indistinctus YIT 12060',
#   'Tannerella forsythia 92A2',
#   'Bacteroides reticulotermitis JCM 10512',
#   'Bacteroides uniformis dnLKV2',
#   'Hoylesella saccharolytica F0055',
#   'Prevotella multiformis DSM 16608'],
#  5: ['Pseudonocardia dioxanivorans CB1190',
#   'Prescottella equi ATCC 33707',
#   'Mycobacterium tuberculosis H37Rv',
#   'Mycobacterium tuberculosis variant bovis AF2122/97',
#   'Patulibacter medicamentivorans',
#   'Aeromicrobium marinum DSM 15272',
#   'Gordonia amarae NBRC 15530',
#   'Nocardia brasiliensis ATCC 700358',
#   'Gordonia aichiensis NBRC 108223',
#   'Mycobacterium avium subsp. paratuberculosis K-10',
#   'Mycolicibacter sinensis',
#   'Segniliparus rugosus ATCC BAA-974',
#   'Mycolicibacterium chubuense NBB4',
#   'Mycolicibacterium hassiacum DSM 44199',
#   'Rhodococcus rhodnii LMG 5362',
#   'Mycobacterium tuberculosis H37Ra',
#   'Mycobacterium tuberculosis CDC1551',
#   'Nocardia farcinica IFM 10152',
#   'Mycolicibacterium thermoresistibile ATCC 19527',
#   'Nocardia cyriacigeorgica GUH-2',
#   'Saccharomonospora marina XMU15',
#   'Mycolicibacterium neoaurum VKM Ac-1815D',
#   'Gordonia polyisoprenivorans VH2',
#   'Nocardia asteroides NBRC 15531',
#   'Gordonia soli NBRC 108243',
#   'Segniliparus rotundus DSM 44985',
#   'Mycolicibacterium rhodesiae NBB3',
#   'Gordonia bronchialis DSM 43247',
#   'Hoyosella subflava DQS3-9A1',
#   'Gordonia rhizosphera NBRC 16068',
#   'Nocardia nova SH22a',
#   'Mycolicibacterium smegmatis MC2 155',
#   'Mycobacterium marinum M',
#   'Tsukamurella paurometabola DSM 20162',
#   'Mycobacterium leprae TN'],
#  6: ['Alcanivorax borkumensis SK2',
#   'Acinetobacter rudis CIP 110305',
#   'Candidatus Paraburkholderia kirkii UZHbot1',
#   'Kangiella koreensis DSM 16069',
#   'Acinetobacter pittii PHEA-2',
#   'Psychrobacter arcticus 273-4',
#   'Pelistega indica',
#   'gamma proteobacterium HTCC5015',
#   'Acinetobacter brisouii CIP 110357',
#   'Polynucleobacter asymbioticus QLW-P1DMWA-1',
#   'Acinetobacter guillouiae NIPH 991',
#   'Xylella fastidiosa Temecula1',
#   'Acinetobacter indicus CIP 110367'],
#  7: ['Nocardioides sp. JS614',
#   'marine actinobacterium PHSC20C1',
#   'Conexibacter woesei DSM 14684',
#   'Kineococcus radiotolerans SRS30216 = ATCC BAA-149',
#   'Acidothermus cellulolyticus 11B',
#   'Arthrobacter nitrophenolicus',
#   'Brachybacterium faecium DSM 4810',
#   'Saccharomonospora viridis DSM 43017',
#   'Saccharomonospora glauca K62',
#   'Janibacter sp. HTCC2649',
#   'Arthrobacter globiformis NBRC 12137',
#   'Beutenbergia cavernae DSM 12333',
#   'Renibacterium salmoninarum ATCC 33209',
#   'Cellulomonas flavigena DSM 20109',
#   'Nocardioides sp. CF8',
#   'Candidatus Protofrankia datiscae',
#   'Arthrobacter crystallopoietes BAB-32',
#   'Intrasporangium calvum DSM 43043',
#   'Microbacterium maritypicum MF109',
#   'Phycicoccus elongatus Lp2',
#   'Agrococcus pavilionensis RW1',
#   'Microlunatus phosphovorus NM-1',
#   'Brevibacterium casei S18',
#   'Austwickia chelonae NBRC 105200',
#   'Blastococcus saxobsidens DD2',
#   'Deinococcus deserti VCD115',
#   'Nakamurella multipartita DSM 44233',
#   'Kineosphaera limosa NBRC 100340',
#   'Cellulomonas gilvus ATCC 13127',
#   'Modestobacter italicus',
#   'Isoptericola variabilis 225',
#   'Geodermatophilus obscurus DSM 43160',
#   'Mobilicoccus pelagius NBRC 104925',
#   'Cellulomonas fimi ATCC 484',
#   'Arthrobacter sp. FB24',
#   'Xylanimonas cellulosilytica DSM 15894',
#   'Ilumatobacter coccineus YM16-304',
#   'Acidimicrobium ferrooxidans DSM 10331',
#   'Thermobispora bispora DSM 43833'],
#  8: ['Halanaerobium saccharolyticum subsp. saccharolyticum DSM 6643',
#   'Dethiosulfovibrio peptidovorans DSM 11002',
#   'Pseudothermotoga thermarum DSM 5069',
#   'Halanaerobium praevalens DSM 2228',
#   'Aminomonas paucivorans DSM 12260',
#   'Ilyobacter polytropus DSM 2926',
#   'Acetomicrobium mobile DSM 13181',
#   'Thermanaerovibrio acidaminovorans DSM 6589',
#   'Thermovirga lienii DSM 17291',
#   'Fusobacterium animalis ATCC 51191',
#   'Aminobacterium colombiense DSM 12261',
#   'Jonquetella anthropi DSM 22815',
#   'Halanaerobium hydrogeniformans'],
#  9: ['Bermanella marisrubri',
#   'Alloalcanivorax dieselolei B5',
#   'Cycloclasticus sp. P1',
#   'Betaproteobacteria bacterium MOLA814',
#   'gamma proteobacterium HdN1',
#   'Laribacter hongkongensis HLHK9',
#   'Lautropia mirabilis ATCC 51599',
#   'Halomonas sp. BC04',
#   'Salinisphaera shabanensis E1L3A',
#   'Isoalcanivorax pacificus W11-5',
#   'Neptuniibacter caesariensis',
#   'Limnobacter sp. MED105',
#   'Litchfieldella anticariensis FP35 = DSM 16096',
#   'Spiribacter curvatus',
#   'Halomonas sp. GFAJ-1',
#   'Thalassolituus oleivorans MIL-1',
#   'Marinobacter sp. BSs20148',
#   'Halomonas huangheensis',
#   'Chromohalobacter israelensis DSM 3043',
#   'gamma proteobacterium IMCC1989'],
#  10: ['Clostridium cellulovorans 743B',
#   'Acetivibrio clariflavus DSM 19732',
#   'Ruminococcus albus 8',
#   'Acetivibrio thermocellus ATCC 27405',
#   'Mahella australiensis 50-1 BON',
#   'Acetivibrio straminisolvens JCM 21531',
#   'Ruminiclostridium cellulolyticum H10',
#   'Cellulosilyticum lentocellum DSM 5427',
#   'Ruminococcus champanellensis 18P13 = JCM 17042',
#   'Thermoclostridium stercorarium subsp. stercorarium DSM 8532',
#   'Ruminiclostridium cellobioparum subsp. termitidis CT1112',
#   'Lachnoclostridium phytofermentans ISDg',
#   'Ruminococcus flavefaciens 007c'],
#  11: ['Methylobacter tundripaludum SV96',
#   'Marichromatium purpuratum 984',
#   'Methylobacillus flagellatus KT',
#   'Methylotuvimicrobium alcaliphilum 20Z',
#   'endosymbiont of Tevnia jerichonana (vent Tica)',
#   'Methylophaga frappieri',
#   'Nitrococcus mobilis Nb-231',
#   'Nitrosomonas europaea ATCC 19718',
#   'Halothiobacillus neapolitanus c2',
#   'Methylophaga thiooxydans DMS010',
#   'Methylotenera mobilis JLW8',
#   'Methylomicrobium album BG8',
#   'Thioalkalivibrio paradoxus ARh 1',
#   'Nitrosospira multiformis ATCC 25196',
#   'Sulfuricella denitrificans skB26',
#   'endosymbiont of unidentified scaly snail isolate Monju',
#   'Thiocystis violascens DSM 198',
#   'Allochromatium vinosum DSM 180',
#   'Methyloglobulus morosus KoM1',
#   'Acidithiobacillus caldus SM-1',
#   'Magnetococcus marinus MC-1',
#   'Methylococcus capsulatus str. Bath',
#   'Nitrosococcus oceani ATCC 19707',
#   'Methylomonas methanica MC09',
#   'Thioflavicoccus mobilis 8321',
#   'Alkalilimnicola ehrlichii MLHE-1',
#   'Thiobacillus denitrificans ATCC 25259',
#   'Thiorhodovibrio frisius',
#   'Gallionella capsiferriformans ES-2',
#   'gamma proteobacterium IMCC2047',
#   'Thiocapsa marina 5811',
#   'Acidithiobacillus ferrooxidans ATCC 23270',
#   'Thioalkalivibrio sulfidiphilus HL-EbGr7',
#   'Methylophaga aminisulfidivorans MP',
#   'Beggiatoa alba B18LD',
#   'Nitrosomonas sp. AL212',
#   'Nitrosococcus halophilus Nc 4',
#   'Methylotenera versatilis 301',
#   'Candidatus Symbiobacter mobilis CR',
#   'Methylophaga lonarensis MPL',
#   'Mariprofundus ferrooxydans PV-1',
#   'Methylovorus glucosotrophus SIP3-4',
#   'Sideroxydans lithotrophicus ES-1',
#   'Thiothrix nivea DSM 5205',
#   'Halorhodospira halophila SL1',
#   'Nitrosospira lacus'],
#  12: ['Caulobacter vibrioides NA1000',
#   'Hirschia baltica ATCC 49814',
#   'alpha proteobacterium IMCC14465',
#   'Gammaproteobacteria bacterium MOLA455',
#   'Xanthomonas campestris pv. campestris str. ATCC 33913',
#   'gamma proteobacterium BDW918',
#   'Pseudoxanthomonas spadix BD-a59',
#   'Stenotrophomonas maltophilia K279a',
#   'Oceanicaulis sp. HTCC2633',
#   'Luminiphilus syltensis NOR5-1B',
#   'Asticcacaulis sp. YBE204',
#   'Xanthomonas albilineans GPE PC73',
#   'Brevundimonas subvibrioides ATCC 15264',
#   'Asticcacaulis sp. AC402',
#   'marine gamma proteobacterium HTCC2080',
#   'gamma proteobacterium HIMB55',
#   'Frateuria aurantia DSM 6220',
#   'Xanthomonas oryzae pv. oryzae KACC 10331',
#   'Aequoribacter fuscus',
#   'Congregibacter litoralis KT71',
#   'Hydrocarboniphaga effusa AP103',
#   'Maricaulis maris MCS10',
#   'marine gamma proteobacterium HTCC2143',
#   'Hyphomonas neptunium ATCC 15444',
#   'Asticcacaulis benevestitus DSM 16100 = ATCC BAA-896',
#   'marine gamma proteobacterium HTCC2148',
#   'Massilia timonae CCUG 45783',
#   'Pseudoxanthomonas suwonensis 11-1',
#   'SAR86 cluster bacterium SAR86E',
#   'Rhodanobacter fulvus Jip2',
#   'Caulobacter vibrioides CB15',
#   'Asticcacaulis sp. AC466',
#   'Acinetobacter gerneri DSM 14967 = CIP 107464 = MTCC 9824',
#   'Rhodanobacter spathiphylli B39'],
#  13: ['Vibrio azureus NBRC 104587',
#   'Shewanella woodyi ATCC 51908',
#   'Ferrimonas balearica DSM 9799',
#   'Catenovulum agarivorans DS-2',
#   'Shewanella amazonensis SB2B',
#   'Idiomarina loihiensis L2TR',
#   'Idiomarina xiamenensis 10-D-4',
#   'Aliivibrio fischeri ES114',
#   'Oceanimonas sp. GK1',
#   'Gallaecimonas xiamenensis 3-C-1',
#   'Shewanella loihica PV-4',
#   'Teredinibacter turnerae T7901',
#   'Vibrio cholerae O1 biovar El Tor str. N16961',
#   'Tolumonas auensis DSM 9187',
#   'Aliiglaciecola lipolytica E3',
#   'Plesiomonas shigelloides 302-73',
#   'Paraglaciecola arctica BSs20135',
#   'Vibrio ezurae NBRC 102218',
#   'Cellvibrio japonicus Ueda107',
#   'Shewanella sediminis HAW-EB3',
#   'Photobacterium profundum SS9',
#   'Reinekea blandensis MED297',
#   'Paraglaciecola psychrophila 170',
#   'Vibrio nigripulchritudo',
#   'Shewanella oneidensis MR-1',
#   'Rheinheimera nanhaiensis E407-8',
#   'Grimontia hollisae CIP 101886',
#   'Brumicola nitratireducens FR1064',
#   'Psychromonas ingrahamii 37',
#   'Vibrio caribbeanicus ATCC BAA-2122',
#   'Simiduia agarivorans SA1 = DSM 21679',
#   'Shewanella pealeana ATCC 700345',
#   'Shewanella frigidimarina NCIMB 400',
#   'Photobacterium damselae subsp. damselae CIP 102761',
#   'Shewanella violacea DSS12',
#   'Pseudoalteromonas translucida TAC125',
#   'Psychromonas sp. CNPT3',
#   'Shewanella denitrificans OS217',
#   'Aeromonas hydrophila subsp. hydrophila ATCC 7966',
#   'Saccharophagus degradans 2-40'],
#  14: ['Brevibacillus brevis NBRC 100599',
#   'Paenibacillus dendritiformis C454',
#   'Paenibacillus sp. JCM 10914',
#   'Brevibacillus laterosporus LMG 15441',
#   'Brevibacillus borstelensis AK1',
#   'Paenibacillus sp. HGF7',
#   'Paenibacillus mucilaginosus 3016',
#   'Halalkalibacter hemicellulosilyticusJCM 9152',
#   'Thermobacillus composti KWC4',
#   'Brevibacillus panacihumi W25',
#   'Paenibacillus sp. oral taxon 786 str. D14',
#   'Paenibacillus pini JCM 16418'],
#  15: ['Streptomyces coelicolor A3(2)',
#   'Streptomyces turgidiscabies Car8',
#   'Streptomyces bingchenggensis BCW-1',
#   'Streptomyces sp. SirexAA-E',
#   'Kitasatospora setae KM-6054',
#   'Actinoplanes missouriensis 431',
#   'Streptomyces zinciresistens K42',
#   'Streptomyces afghaniensis 772',
#   'Microbispora sp. ATCC PTA-5024',
#   'Streptosporangium roseum DSM 43021',
#   'Saccharothrix espanaensis DSM 44229',
#   'Thermomonospora curvata DSM 43183',
#   'Actinoplanes sp. N902-109',
#   'Streptomyces auratus AGR0001',
#   'Pseudofrankia inefficax',
#   'Amycolatopsis keratiniphila',
#   'Saccharopolyspora erythraea NRRL 2338',
#   'Streptomyces ipomoeae 91-03',
#   'Actinoplanes friuliensis DSM 7358',
#   'Streptomyces collinus Tu 365',
#   'Salinispora tropica CNB-440',
#   'Streptomyces venezuelae ATCC 10712',
#   'Streptomyces viridochromogenes DSM 40736',
#   'Stackebrandtia nassauensis DSM 44728',
#   'Streptantibioticus cattleyicolor NRRL 8057 = DSM 46488',
#   'Amycolatopsis mediterranei U32',
#   'Kutzneria albida DSM 43870',
#   'Streptomycetaceae bacterium MP113-05',
#   'Streptomyces roseochromogenus subsp. oscitans DS 12.976',
#   'Nocardiopsis dassonvillei subsp. dassonvillei DSM 43111',
#   'Streptomyces sp. HPH0547',
#   'Streptomyces avermitilis MA-4680 = NBRC 14893',
#   'Actinoplanes sp. SE50/110',
#   'Streptomyces davaonensis JCM 4913',
#   'Kribbella flavida DSM 17836',
#   'Actinosynnema mirum DSM 43827',
#   'Frankia casuarinae',
#   'Streptomyces clavuligerus',
#   'Micromonospora sp. ATCC 39149',
#   'Streptomyces scabiei 87.22',
#   'Streptomyces pristinaespiralis ATCC 25486',
#   'Catenulispora acidiphila DSM 44928',
#   'Frankia alni ACN14a',
#   'Streptomyces griseoaurantiacus M045',
#   'Streptomyces aurantiacus JA 4570',
#   'Micromonospora lupini str. Lupac 08',
#   'Actinokineospora spheciospongiae',
#   'Streptomyces sp. HGB0020'],
#  16: ['Polaribacter irgensii 23-P',
#   'Riemerella anatipestifer RA-CH-1',
#   'Sphingobacterium spiritivorum ATCC 33861',
#   'Weeksella virosa DSM 16922',
#   'Echinicola vietnamensis DSM 17526',
#   'Galbibacter orientalis DSM 19592',
#   'Marivirga tractuosa DSM 4126',
#   'Bergeyella zoohelcum ATCC 43767',
#   'Indibacter alkaliphilus LW1',
#   'Imtechella halotolerans K1',
#   'Algoriphagus machipongonensis',
#   'Bernardetia litoralis DSM 6794',
#   'Belliella baltica DSM 15883',
#   'Gillisia limnaea DSM 15749',
#   'Capnocytophaga canimorsus Cc5',
#   'Dyadobacter fermentans DSM 18053',
#   'Zobellia galactanivorans',
#   'Zhouia amylolytica AD3',
#   'Allomuricauda ruestringensis DSM 13258',
#   'Capnocytophaga sp. oral taxon 332 str. F0381',
#   'Flavobacteriaceae bacterium 3519-10',
#   'Lacinutrix sp. 5H-3-7-4',
#   'Rhodonellum psychrophilum GCM71 = DSM 17998',
#   'Sphingobacterium paucimobilis HER1398',
#   'Polaribacter sp. MED152',
#   'Capnocytophaga ochracea DSM 7271',
#   'Cytophaga hutchinsonii ATCC 33406',
#   'Cesiribacter andamanensis AMV16',
#   'Cyclobacterium marinum DSM 745',
#   'Pedobacter heparinus DSM 2366',
#   'Flavobacterium psychrophilum JIP02/86',
#   'Psychroflexus gondwanensis ACAM 44',
#   'Haliscomenobacter hydrossis DSM 1100',
#   'Cecembia lonarensis LW9',
#   'Maribacter sp. HTCC2170',
#   'Fulvivirga imtechensis AK7',
#   'Leeuwenhoekiella blandensis MED217',
#   'Fibrella aestuarina BUZ 2',
#   'Microscilla marina ATCC 23134',
#   'Capnocytophaga sp. oral taxon 338 str. F0234',
#   'Formosa agariphila KMM 3901',
#   'Mariniradius saccharolyticus AK6',
#   'Mucilaginibacter paludis DSM 18603',
#   'Pedobacter sp. BAL39',
#   'Candidatus Amoebophilus asiaticus 5a2',
#   'Flavobacteria bacterium BBFL7',
#   'Ornithobacterium rhinotracheale DSM 15997',
#   'Flavobacterium indicum GPTSA100-9 = DSM 17447',
#   'Flavobacteria bacterium MS024-3C',
#   'Flavobacteriales bacterium ALC-1',
#   'Solitalea canadensis DSM 3403',
#   'Flavobacterium columnare ATCC 49512',
#   'Runella slithyformis DSM 19594',
#   'Robiginitalea biformata HTCC2501',
#   'Owenweeksia hongkongensis DSM 17368',
#   'Flavobacterium branchiophilum FL-15',
#   'Saprospira grandis str. Lewin',
#   'Niabella soli DSM 19437',
#   'Nitritalea halalkaliphila LW7',
#   'Ignavibacterium album JCM 16511',
#   'Leadbetterella byssophila DSM 17132',
#   'Fluviicola taffensis DSM 16823',
#   'Arcticibacter svalbardensis MN12-7',
#   'Croceibacter atlanticus HTCC2559',
#   'Cellulophaga lytica DSM 7489',
#   'Galbibacter marinus',
#   'Fibrisoma limi BUZ 3',
#   'Winogradskyella psychrotolerans RS-3',
#   'Flavobacteria bacterium BAL38',
#   'Bizionia argentinensis JUB59',
#   'Lunatimonas lonarensis',
#   'Pseudopedobacter saltans DSM 12145'],
#  17: ['Geobacillus kaustophilus HTA426',
#   'Alicyclobacillus acidocaldarius subsp. acidocaldarius DSM 446',
#   'Shouchella clausii KSM-K16',
#   'Sporolactobacillus laevolacticus DSM 442',
#   'Bacillus licheniformis DSM 13 = ATCC 14580',
#   'Bacillus infantis NRRL B-14911',
#   'Alkalihalobacillus alcalophilus ATCC 27647 = CGMCC 1.3604',
#   'Neobacillus bataviensis LMG 21833',
#   'Schinkia azotoformans LMG 9581',
#   'Bacillus anthracis',
#   'Amphibacillus xylanus NBRC 15112',
#   'Oceanobacillus iheyensis HTE831',
#   'Staphylococcus epidermidis RP62A',
#   'Thermaerobacter marianensis DSM 12885',
#   'Bacillus sp. 1NLA3E',
#   'Fictibacillus macauensis ZFHKF-1',
#   'Bacillus subtilis subsp. subtilis str. 168',
#   'Exiguobacterium chiriqhucha RW-2',
#   'Salimicrobium jeotgali',
#   'Halalkalibacter wakoensis JCM 9140',
#   'Priestia megaterium QM B1551',
#   'Staphylococcus aureus subsp. aureus NCTC 8325',
#   'Mesobacillus boroniphilus JCM 21738',
#   'Alkalihalophilus pseudofirmus OF4',
#   'Halobacillus sp. BAB-2008',
#   'Viridibacillus arenosi FSL R5-213',
#   'Gracilibacillus halophilus YIM-C55.5',
#   'Bacillus smithii 7_3_47FAA',
#   'Halobacillus halophilus DSM 2266',
#   'Staphylococcus massiliensis S46',
#   'Paenisporosarcina sp. HGH0030',
#   'Halalkalibacterium halodurans C-125',
#   'Gracilibacillus boraciitolerans JCM 21714',
#   'Bacillus cereus ATCC 14579',
#   'Paenibacillus curdlanolyticus YK9',
#   'Macrococcoides caseolyticum JCSC5402',
#   'Halalkalibacter akibai JCM 9157',
#   'Exiguobacterium artemiae 255-15',
#   'Evansella cellulosilytica DSM 2522',
#   'Staphylococcus saprophyticus subsp. saprophyticus ATCC 15305 = NCTC 7292',
#   'Bhargavaea cecembensis DSE10',
#   'Solibacillus silvestris StLB046'],
#  18: ['Candidatus Pelagibacter sp. IMCC9063',
#   'Legionella longbeachae NSW150',
#   'Bartonella bovis 91-4',
#   'Bacteriovorax sp. DB6_IX',
#   'Candidatus Endolissoclinum faulkneri L5',
#   'Bacteriovorax sp. BSW11_IV',
#   'Candidatus Babela massiliensis',
#   'Legionella oakridgensis ATCC 33761 = DSM 21215',
#   'Bacteriovorax sp. Seq25_V',
#   'Halobacteriovorax marinus SJ',
#   'Candidatus Protochlamydia amoebophila UWE25',
#   'Waddlia chondrophila WSU 86-1044',
#   'Liberibacter crescens BT-1',
#   'Coxiella burnetii RSA 493',
#   'Spiribacter salinus M19-40',
#   'Candidatus Liberibacter americanus str. Sao Paulo',
#   'Orientia tsutsugamushi str. Boryong',
#   'Legionella pneumophila subsp. pneumophila str. Philadelphia 1',
#   'Legionella drancourtii LLAP12',
#   'Pseudobdellovibrio exovorus JSS',
#   'Candidatus Midichloria mitochondrii IricVA',
#   'Leptospira borgpetersenii str. 200701203',
#   'Bdellovibrio bacteriovorus HD100',
#   'Holospora obtusa F1',
#   'Candidatus Pelagibacter ubique HTCC1062',
#   'Simkania negevensis Z',
#   'Micavibrio aeruginosavorus ARL-13',
#   'Parachlamydia acanthamoebae UV-7',
#   'Chlamydia trachomatis D/UW-3/CX'],
#  19: ['Burkholderia multivorans ATCC 17616',
#   'Acidovorax sp. CF316',
#   'Paracidovorax avenae ATCC 19860',
#   'Verminephrobacter eiseniae EF01-2',
#   'unknown',
#   'Herbaspirillum seropedicae SmR1',
#   'Alicycliphilus denitrificans K601',
#   'Cupriavidus necator H16',
#   'Cupriavidus metallidurans CH34',
#   'Delftia acidovorans SPH-1',
#   'Bordetella pertussis Tohama I',
#   'Burkholderia pseudomallei K96243',
#   'Advenella mimigardefordensis DPN7',
#   'Acidovorax delafieldii 2AN',
#   'Hylemonella gracilis ATCC 19624',
#   'Polaromonas sp. JS666',
#   'Ramlibacter tataouinensis TTB310',
#   'Paraburkholderia graminis C4D1M',
#   'Ralstonia sp. 5_2_56FAA',
#   'Paraburkholderia phymatum STM815',
#   'Collimonas fungivorans Ter331',
#   'Alcaligenes sp. EGD-AK7',
#   'Herbaspirillum sp. YR522',
#   'Bordetella avium 197N'],
#  20: ['Phormidium nigroviride PCC 7112',
#   'Calothrix sp. PCC 6303',
#   'Chamaesiphon minutus PCC 6605',
#   'Oxynema acuminatum PCC 6304',
#   'Nostoc sp. PCC 7524',
#   'Gloeocapsa sp. PCC 7428',
#   'Rivularia sp. PCC 7116',
#   'Nostoc sp. PCC 7107',
#   'Pleurocapsa sp. PCC 7327',
#   'Geitlerinema sp. PCC 7407',
#   'Acaryochloris marina MBIC11017',
#   'Cylindrospermum stagnale PCC 7417',
#   'Thalassoporum mexicanum PCC 7367',
#   'Calothrix sp. PCC 7507',
#   'Kamptonema sp. PCC 6506',
#   'Anabaena cylindrica PCC 7122',
#   'Stanieria cyanosphaera PCC 7437',
#   'Crinalium epipsammum PCC 9333',
#   'Xenococcus sp. PCC 7305',
#   'Coleofasciculus chthonoplastes PCC 7420',
#   'Allocoleopsis franciscana PCC 7113',
#   'Gloeocapsa sp. PCC 73106',
#   'Chroococcidiopsis thermalis PCC 7203',
#   'Gloeobacter violaceus PCC 7421',
#   'Leptolyngbyaceae cyanobacterium JSC-12',
#   'Fischerella thermalis JSC-11',
#   'Crocosphaera watsonii WH 8501',
#   'Lyngbya sp. PCC 8106',
#   'Limnospira maxima CS-328',
#   'Anabaena sp. 90',
#   'Crocosphaera subtropica ATCC 51142',
#   'Rippkaea orientalis PCC 8801',
#   'Nostoc punctiforme PCC 73102',
#   'Nostoc sp. PCC 7120 = FACHB-418',
#   'Gloeobacter kilaueensis JS1',
#   'Halothece sp. PCC 7418',
#   'Gloeothece citriformis PCC 7424',
#   'Gloeothece verrucosa PCC 7822',
#   'Synechococcus sp. PCC 7335'],
#  21: ['Sorangium cellulosum So ce56',
#   'Myxococcus xanthus DK 1622',
#   'Haliangium ochraceum DSM 14365',
#   'Plesiocystis pacifica SIR-1'],
#  22: ['Celeribacter baekdonensis B30',
#   'Rhodobacteraceae bacterium HTCC2150',
#   'Oceaniovalibus guishaninsula JLT2003',
#   'Cereibacter sphaeroides 2.4.1',
#   'Salipiger bermudensis HTCC2601',
#   'Dinoroseobacter shibae DFL 12 = DSM 16493',
#   'alpha proteobacterium HIMB59',
#   'Rubellimicrobium thermophilum DSM 16684',
#   'Ruegeria pomeroyi DSS-3',
#   'Roseobacter denitrificans OCh 114',
#   'Paracoccus aminophilus JCM 7686',
#   'Aurantimonas manganoxydans SI85-9A1',
#   'Litoreibacter arenae DSM 19593',
#   'Roseobacter sp. SK209-2-6',
#   'Roseovarius nubinhibens ISM',
#   'Salipiger mucosus DSM 16094',
#   'Polymorphum gilvum SL003B-26A1',
#   'Roseobacter sp. GAI101',
#   'Rhodobacteraceae bacterium HIMB11',
#   'Maritimibacter alkaliphilus HTCC2654',
#   'Yoonia vestfoldensis SKA53',
#   'Pseudooceanicola batsensis HTCC2597',
#   'Ketogulonicigenium vulgare WSH-001',
#   'Fulvimarina pelagi HTCC2506',
#   'Oceanibaculum indicum P24',
#   'Jannaschia sp. CCS1',
#   'SAR116 cluster alpha proteobacterium HIMB100',
#   'Ruegeria sp. TM1040',
#   'Candidatus Pelagibacter sp. HTCC7211',
#   'Octadecabacter arcticus 238',
#   'Brucella abortus 2308',
#   'Thalassobium sp. R2A62',
#   'Lutibaculum baratangense AMV1',
#   'Hoeflea phototrophica DFL-43',
#   'Rhodobacter capsulatus SB 1003',
#   'Rhodobacterales bacterium HTCC2255',
#   'Roseivivax marinus',
#   'Rhodobacter ferrooxidans',
#   'Paracoccus denitrificans PD1222',
#   'Candidatus Puniceispirillum marinum IMCC1322',
#   'Roseibium sp. TrichSKD4',
#   'alpha proteobacterium BAL199',
#   'Ahrensia sp. R2A130',
#   'Rhodobacteraceae bacterium HTCC2083',
#   'Oceanicola granulosus HTCC2516'],
#  23: ['Rhodopirellula sallentina SM41',
#   'Rhodopirellula maiorica SM1',
#   'Pirellula staleyi DSM 6068',
#   'Lentisphaera araneosa HTCC2155',
#   'Isosphaera pallida ATCC 43644',
#   'Rubinisphaera brasiliensis DSM 5305',
#   'Rhodopirellula baltica SH 1',
#   'Planctopirus limnophila DSM 3776',
#   'Singulisphaera acidiphila DSM 18658',
#   'Opitutaceae bacterium TAV5'],
#  24: ['Mycoplasmopsis agalactiae PG2',
#   'Mycoplasma haemocanis str. Illinois',
#   'Mycoplasmoides gallisepticum str. R(low)',
#   'Spiroplasma apis B31',
#   'Mycoplasma mobile 163K',
#   'Candidatus Phytoplasma mali AT',
#   'Mycoplasma putrefaciens Mput9231',
#   'Spiroplasma syrphidicola EA-1',
#   'Mycoplasmopsis cynos C142',
#   'Malacoplasma penetrans HF-2',
#   'Spiroplasma mirum ATCC 29335',
#   'Mycoplasmopsis anatis 1340',
#   'Metamycoplasma arthritidis 158L3-1',
#   'Metamycoplasma alkalescens 14918',
#   'Mycoplasmopsis columbina SF7',
#   'Mycoplasmopsis canis UFG4',
#   'Spiroplasma culicicola AES-1',
#   'Spiroplasma sabaudiense Ar-1343',
#   'Metamycoplasma hominis ATCC 23114',
#   'Mesomycoplasma conjunctivae HRC/581',
#   'Mycoplasmopsis synoviae 53',
#   'Mycoplasmopsis bovigenitalium 51080',
#   'Mycoplasma wenyonii str. Massachusetts',
#   'Candidatus Mycoplasma haematolamae str. Purdue',
#   'Mycoplasmopsis pulmonis UAB CTIP',
#   'Mycoplasma crocodyli MP145',
#   'Candidatus Phytoplasma australiense',
#   'Mycoplasmoides genitalium G37',
#   'Spiroplasma diminutum CUAS-1',
#   'Mycoplasma parvum str. Indiana',
#   'Spiroplasma taiwanense CT-1',
#   'Mesoplasma florum L1',
#   'Mycoplasma suis str. Illinois',
#   'Ureaplasma parvum serovar 3 str. ATCC 700970',
#   'Mesomycoplasma bovoculi M165/69',
#   'Mycoplasmopsis fermentans PG18'],
#  25: ['Methyloversatilis universalis FAM5',
#   'Azoarcus olearius',
#   'Thauera linaloolentis 47Lol = DSM 12138',
#   'Thauera sp. 27',
#   'Methylibium petroleiphilum PM1',
#   'Rubrivivax gelatinosus IL144',
#   'Rhodoferax ferrireducens T118',
#   'Azoarcus sp. KH32C',
#   'Herminiimonas arsenicoxydans',
#   'Thauera terpenica 58Eu',
#   "Leptospira biflexa serovar Patoc strain 'Patoc 1 (Paris)'",
#   'Oxalobacteraceae bacterium IMCC9480',
#   'Thauera aminoaromatica',
#   'Leptothrix cholodnii SP-6',
#   'Polaromonas naphthalenivorans CJ2',
#   'Burkholderiales bacterium JOSHI_001',
#   'Leptospira weilii serovar Topaz str. LT2116',
#   'Aromatoleum aromaticum EbN1'],
#  26: ['Melioribacter roseus P3M-2',
#   'Chloracidobacterium thermophilum B',
#   'Phycisphaera mikurensis NBRC 102666',
#   'Elusimicrobium minutum Pei191',
#   'Akkermansia muciniphila ATCC BAA-835',
#   'Nitrospina gracilis 3/211',
#   'Saccharicrinis fermentans DSM 9555 = JCM 21142',
#   'Chthonomonas calidirosea T49',
#   'Salinibacter ruber DSM 13855',
#   'Caldithrix abyssi DSM 13497',
#   'Chloroherpeton thalassium ATCC 35110'],
#  27: ['Desulfatibacillum aliphaticivorans',
#   'Pseudodesulfovibrio piezophilus C1TLV30',
#   'Desulfocapsa sulfexigens DSM 10523',
#   'Thermodesulfovibrio yellowstonii DSM 11347',
#   'Solidesulfovibrio carbinoliphilus subsp. oakridgensis',
#   'Desulfosudis oleivorans Hxd3',
#   'Desulfobulbus propionicus DSM 2032',
#   'Desulfotalea psychrophila LSv54',
#   'Desulfarculus baarsii DSM 2075',
#   'Geobacter sulfurreducens PCA',
#   'Oleidesulfovibrio alaskensis G20',
#   'Citrifermentans bemidjiense Bem',
#   'Maridesulfovibrio salexigens DSM 2638',
#   'Desulfomonile tiedjei DSM 6799',
#   'Desulfurispirillum indicum S5',
#   'Denitrovibrio acetiphilus DSM 12809',
#   'Syntrophotalea carbinolica DSM 2380',
#   'Bilophila wadsworthia 3_1_6',
#   'Syntrophus aciditrophicus SB',
#   'Desulfotignum phosphitoxidans DSM 13687',
#   'Desulfobacula toluolica Tol2',
#   'delta proteobacterium NaphS2',
#   'Desulfovibrio sp. X2',
#   'Geotalea daltonii FRC-32',
#   'Alkalidesulfovibrio alkalitolerans DSM 16529',
#   'Desulfococcus multivorans DSM 2059',
#   'Geobacter metallireducens GS-15',
#   'Syntrophobacter fumaroxidans MPOB',
#   'Calditerrivibrio nitroreducens DSM 19672',
#   'Desulfohalobium retbaense DSM 5692',
#   'Desulfurivibrio alkaliphilus AHT 2',
#   'Deferribacter desulfuricans SSM1',
#   'Thermodesulfatator indicus DSM 15286',
#   'Pelobacter propionicus DSM 2379',
#   'Megalodesulfovibrio gigas DSM 1382 = ATCC 19364',
#   'Geotalea uraniireducens Rf4',
#   'Flexistipes sinusarabici DSM 4947',
#   'Desulfocurvibacter africanus subsp. africanus str. Walvis Bay',
#   'Desulfovibrio sp. 6_1_46AFAA',
#   'Desulfomicrobium baculatum DSM 4028',
#   'Trichlorobacter lovleyi SZ',
#   'Desulfobacca acetoxidans DSM 11109',
#   'Nitratidesulfovibrio vulgaris str. Hildenborough',
#   'Desulfobacter postgatei 2ac9',
#   'Desulforapulum autotrophicum HRM2',
#   'Desulfuromonas acetoxidans DSM 684',
#   'Wolinella succinogenes DSM 1740',
#   'Desulfonatronospira thiodismutans ASO3-1'],
#  28: ['Leptospirillum ferrodiazotrophum',
#   'Anaeromyxobacter sp. Fw109-5',
#   'Turneriella parva DSM 21527',
#   'Chlorobaculum tepidum TLS',
#   'Leptospirillum ferrooxidans C2-3',
#   'Candidatus Jettenia caeni',
#   'Chlorobium phaeobacteroides DSM 266',
#   'Leptonema illini DSM 21528',
#   'Pelodictyon phaeoclathratiforme BU-1',
#   'Nitrospira defluvii',
#   'Chlorobium ferrooxidans DSM 13031',
#   'Pelodictyon luteolum DSM 273',
#   'Leptospira interrogans serovar Lai str. 56601',
#   'Anaeromyxobacter dehalogenans 2CP-C'],
#  29: ['Coraliomargarita akajimensis DSM 45221',
#   'Gemmatimonas aurantiaca T-27',
#   'Corallococcus coralloides DSM 2259',
#   'Verrucomicrobiia bacterium DG1235',
#   'Pedosphaera parvula Ellin514',
#   'Opitutus terrae PB90-1',
#   'Chthoniobacter flavus Ellin428'],
#  30: ['Adlercreutzia caecimuris B7',
#   'Eggerthella lenta DSM 2243',
#   'Desulfoscipio gibsoniae DSM 7213',
#   'Desulforamulus reducens MI-1',
#   'Alkaliphilus metalliredigens QYMF',
#   'Desulfitobacterium hafniense Y51',
#   'Desulfitobacterium metallireducens DSM 15288',
#   'Syntrophomonas wolfei subsp. wolfei str. Goettingen G311',
#   'Desulfitobacterium dichloroeliminans LMG P-21439',
#   'Slackia heliotrinireducens DSM 20476',
#   'Desulfofarcimen acetoxidans DSM 771',
#   'Thermincola potens JR',
#   'Desulforamulus hydrothermalis Lam5 = DSM 18033',
#   'Desulforamulus ruminis DSM 2154',
#   'Desulfotomaculum nigrificans CO-1-SRB',
#   'Alkaliphilus oremlandii OhILAs',
#   'Eggerthella sp. YY7918',
#   'Ammonifex degensii KC4',
#   'Carboxydothermus hydrogenoformans Z-2901',
#   'Gordonibacter pamelaeae 7-10-1-b',
#   'Heliomicrobium modesticaldum Ice1',
#   'Candidatus Desulforudis audaxviator MP104C',
#   'Acetonema longum DSM 6540',
#   'Syntrophobotulus glycolicus DSM 8271',
#   'Pelotomaculum thermopropionicum SI',
#   'Dethiobacter alkaliphilus AHT 1',
#   'Desulfosporosinus orientis DSM 765',
#   'Slackia piriformis YIT 12062',
#   'Desulfosporosinus youngiae DSM 17734',
#   'Slackia exigua ATCC 700122',
#   'Thermosinus carboxydivorans Nor1',
#   'Dehalococcoides mccartyi VS',
#   'Thermacetogenium phaeum DSM 12270',
#   'Syntrophothermus lipocalidus DSM 12680',
#   'Symbiobacterium thermophilum IAM 14863'],
#  31: ['Methylorubrum extorquens AM1',
#   'Hyphomicrobium denitrificans ATCC 51888',
#   'Hyphomicrobium nitrativorans NL23',
#   'Commensalibacter papalotli (ex Servin-Garciduenas et al. 2014)',
#   'Rhodospirillum rubrum ATCC 11170',
#   'Acetobacter pomorum DM001',
#   'Rhodospirillum centenum SW',
#   'Gluconobacter oxydans 621H',
#   'Nitrobacter hamburgensis X14',
#   'Rhodomicrobium vannielii ATCC 17100',
#   'Nitrobacter winogradskyi Nb-255',
#   'Afipia carboxidovorans OM5',
#   'Granulibacter bethesdensis CGDNIH1',
#   'Gluconobacter morbifer G707',
#   'Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821',
#   'Magnetospirillum gryphiswaldense MSR-1',
#   'Methylocella silvestris BL2',
#   'Nitrobacter sp. Nb-311A',
#   'Beijerinckia indica subsp. indica ATCC 9039',
#   'Caenispirillum salinarum AK4',
#   'Acidocella sp. MX-AZ02',
#   'Hyphomicrobium sp. MC1',
#   'Rhodovulum sp. PH10',
#   'Bartonella tamiae Th239',
#   'Acidiphilium cryptum JF-5',
#   'Gluconacetobacter diazotrophicus PA1 5',
#   'Parvularcula bermudensis HTCC2503'],
#  32: ['Treponema pedis str. T A4',
#   'Treponema pallidum subsp. pallidum str. Nichols',
#   'Leadbettera azotonutricia ZAS-9',
#   'Treponema primitia ZAS-2',
#   'Brachyspira pilosicoli 95/1000',
#   'Treponema denticola ATCC 35405',
#   'Salinispira pacifica',
#   'Treponema saccharophilum DSM 2985',
#   'Gracilinema caldarium DSM 7334',
#   'Parasphaerochaeta coccoides DSM 17374',
#   'Winmispira thermophila DSM 6578',
#   'Treponema succinifaciens DSM 2489',
#   'Treponema vincentii F0403',
#   'Treponema maltophilum ATCC 51939',
#   'Sphaerochaeta globosa str. Buddy',
#   'Treponema sp. JC4',
#   'Sediminispirochaeta smaragdinae DSM 11293',
#   'Spirochaeta africana DSM 8902',
#   'Sphaerochaeta pleomorpha str. Grapes',
#   'Treponema brennaborense DSM 12168'],
#  33: ['Escherichia coli O139:H28 str. E24377A',
#   'Escherichia coli APEC O1',
#   'Yersinia pestis',
#   'Photorhabdus laumondii subsp. laumondii TTO1',
#   'Klebsiella pneumoniae subsp. pneumoniae HS11286',
#   '[Enterobacter] lignolyticus SCF1',
#   'Enterobacteriaceae bacterium strain FGI 57',
#   'Dickeya dadantii 3937',
#   'Rahnella aquatilis CIP 78.65 = ATCC 33071',
#   'Escherichia coli O127:H6 str. E2348/69',
#   'Shigella sonnei Ss046',
#   'Shigella boydii CDC 3083-94',
#   'Serratia sp. DD3',
#   'Cronobacter sakazakii ATCC BAA-894',
#   'Shigella dysenteriae Sd197',
#   'Shimwellia blattae DSM 4481 = NBRC 105725',
#   'Escherichia coli O157:H7',
#   'Salmonella enterica subsp. enterica serovar Typhimurium str. LT2',
#   'Pantoea ananatis LMG 20103',
#   'Pectobacterium atrosepticum SCRI1043',
#   'Shigella flexneri',
#   'Xenorhabdus nematophila ATCC 19061',
#   'Citrobacter koseri ATCC BAA-895',
#   'Candidatus Sodalis pierantonii str. SOPE',
#   'Sodalis praecaptivus',
#   'Erwinia billingiae Eb661',
#   'Erwinia tasmaniensis Et1/99',
#   'Escherichia coli 55989',
#   'Escherichia coli S88',
#   'Xenorhabdus szentirmaii DSM 16338',
#   'Plautia stali symbiont',
#   'Morganella morganii subsp. morganii KT',
#   'Serratia odorifera DSM 4582',
#   'Salmonella enterica subsp. arizonae serovar 62:z4,z23:-',
#   'Atlantibacter hermannii NBRC 105704',
#   'Prodigiosinella confusarubida',
#   'Escherichia coli CFT073',
#   'Escherichia coli K-12',
#   'Escherichia coli O83:H1 str. NRG 857C',
#   'Providencia sneebia DSM 19967'],
#  34: ['[Clostridium] innocuum 2959',
#   'Thomasclavelia ramosa DSM 1402',
#   'Clostridium kluyveri DSM 555',
#   'Pelosinus fermentans JBW45',
#   'Acetobacterium woodii DSM 1030',
#   'Thomasclavelia spiroformis DSM 1552',
#   'Clostridium sp. DL-VIII',
#   'Turicibacter sp. HGF1',
#   'Clostridium novyi NT',
#   'Clostridium tetani E88',
#   'Clostridium acetobutylicum ATCC 824',
#   'Ethanoligenens harbinense YUAN-3',
#   'Clostridium celatum DSM 1785',
#   'Anaerofustis stercorihominis DSM 17244',
#   'Clostridium butyricum E4 str. BoNT E BL5262',
#   'Clostridium perfringens str. 13',
#   'Clostridium thermobutyricum',
#   'Clostridium sp. 7_2_43FAA',
#   'Clostridium sp. BL8',
#   'Clostridium carboxidivorans P7',
#   'Erysipelotrichaceae bacterium 5_2_54FAA',
#   'Clostridium intestinale URNW',
#   'Clostridium sp. MSTE9',
#   'Clostridium botulinum A str. Hall',
#   'Coprobacillus cateniformis',
#   'Gottschalkia acidurici 9a',
#   'Clostridiales bacterium oral taxon 876 str. F0540',
#   'Clostridium pasteurianum BC1',
#   'Clostridium saccharobutylicum DSM 13864',
#   'Clostridium saccharoperbutylacetonicum N1-4(HMT)',
#   'Clostridioides difficile 630',
#   'Haloplasma contractile SSD-17B'],
#  35: ['Actinomyces massiliensis F0489',
#   'Corynebacterium halotolerans YIM 70093 = DSM 44683',
#   'Corynebacterium urealyticum DSM 7109',
#   'Corynebacterium argentoratense DSM 44202',
#   'Micrococcus luteus NCTC 2665',
#   'Corynebacterium sp. KPL1989',
#   'Corynebacterium sp. KPL1821',
#   'Rothia mucilaginosa DY-18',
#   'Jonesia denitrificans DSM 20603',
#   'Bifidobacterium animalis subsp. lactis AD011',
#   'Corynebacterium glutamicum ATCC 13032',
#   'Actinomyces urogenitalis DSM 15434',
#   'Bifidobacterium bifidum BGN4',
#   'Corynebacterium otitidis ATCC 51513',
#   'Winkia neuii BV029A5',
#   'Kocuria rhizophila DC2201',
#   'Parascardovia denticolens DSM 10105 = JCM 12538',
#   'Corynebacterium durum F0235',
#   'Corynebacterium pseudotuberculosis C231',
#   'Bifidobacterium adolescentis ATCC 15703',
#   'Leifsonia xyli subsp. xyli str. CTCB07',
#   'Actinomyces sp. oral taxon 849 str. F0330',
#   'Actinotignum schaalii FB123-CNA-2',
#   'Corynebacterium pyruviciproducens ATCC BAA-1742',
#   'Propionimicrobium lymphophilum ACS-093-V-SCH5',
#   'Corynebacterium efficiens YS-314',
#   'Propionibacterium sp. oral taxon 192 str. F0372',
#   'Actinomyces graevenitzii C83',
#   'Dermabacter sp. HFH0086',
#   'Corynebacterium matruchotii ATCC 14266',
#   'Corynebacterium kroppenstedtii DSM 44385',
#   'Schaalia turicensis ACS-279-V-Col4',
#   'Schaalia cardiffensis F0333',
#   'Propionibacterium freudenreichii subsp. shermanii CIRM-BIA1',
#   'Mobiluncus mulieris ATCC 35239',
#   'Cutibacterium granulosum DSM 20700',
#   'Mobiluncus curtisii ATCC 43063',
#   'Corynebacterium genitalium ATCC 33030',
#   'Actinobaculum sp. oral taxon 183 str. F0552',
#   'Alloscardovia omnicolens F0580',
#   'Corynebacterium maris DSM 45190',
#   'Kocuria palustris PEL',
#   'Bifidobacterium longum NCC2705',
#   'Arcanobacterium haemolyticum DSM 20595',
#   'Corynebacterium jeikeium K411',
#   'Gleimia coleocanis DSM 15436',
#   'Scardovia inopinata F0304',
#   'Tropheryma whipplei str. Twist',
#   'Actinomyces sp. oral taxon 448 str. F0400',
#   'Cutibacterium avidum ATCC 25577',
#   'Corynebacterium resistens DSM 45100',
#   'Brevibacterium mcbrellneri ATCC 49030',
#   'Corynebacterium aurimucosum ATCC 700975',
#   'Corynebacterium vitaeruminis DSM 20294',
#   'Corynebacterium diphtheriae NCTC 13129',
#   'Scardovia wiggsiae F0424',
#   'Actinobaculum massiliense ACS-171-V-Col2'],
#  36: ['Thermus thermophilus HB8',
#   'Truepera radiovictrix DSM 17093',
#   'Roseiflexus castenholzii DSM 13941',
#   'Caldilinea aerophila DSM 14535 = NBRC 104270',
#   'Deinococcus maricopensis DSM 21211',
#   'Deinococcus peraridilitoris DSM 19664',
#   'Deinococcus radiodurans R1 = ATCC 13939 = DSM 20539',
#   'Sphaerobacter thermophilus DSM 20745',
#   'Marinithermus hydrothermalis DSM 14884',
#   'Rubrobacter xylanophilus DSM 9941',
#   'Anaerolinea thermophila UNI-1',
#   'Oceanithermus profundus DSM 14977',
#   'Deinococcus proteolyticus MRP',
#   'Chloroflexus aurantiacus J-10-fl',
#   'Allomeiothermus silvanus DSM 9946'],
#  37: ['Sphingobium indicum UT26S',
#   'Sphingobium ummariense RL-3',
#   'Sphingobium baderi LL03',
#   'Novosphingobium lindaniclasticum LE124',
#   'Novosphingobium aromaticivorans DSM 12444',
#   'Rhizorhabdus wittichii RW1',
#   'Novosphingobium pentaromativorans US6-1',
#   'Sphingomonas sanxanigenens DSM 19645 = NX02',
#   'Sphingobium sp. C100',
#   'Sphingobium indicum BiD32',
#   'Sphingobium chlorophenolicum L-1',
#   'Brevundimonas abyssalis TAR-001',
#   'Erythrobacter litoralis HTCC2594',
#   'Novosphingobium sp. Rr 2-17',
#   'Novosphingobium nitrogenifigens DSM 19370',
#   'Phenylobacterium zucineum HLK1',
#   'Parvibaculum lavamentivorans DS-1',
#   'Pacificimonas flava',
#   'Erythrobacter sp. NAP1',
#   'Sphingopyxis alaskensis RB2256',
#   'Sphingomonas sp. MM-1',
#   'Caenibius tardaugens NBRC 16725',
#   'Sphingobium yanoikuyae ATCC 51230',
#   'Sphingobium sp. SYK-6',
#   'Novosphingobium sp. AP12',
#   'Novosphingobium sp. PP1Y',
#   'Sphingomonas sp. SKA58'],
#  38: ['Acidaminococcus fermentans DSM 20731',
#   'Leptotrichia sp. oral taxon 215 str. W9775',
#   'Acidaminococcus intestini RyC-MR95',
#   'Dialister micraerophilus DSM 19965',
#   'Streptobacillus moniliformis DSM 12112',
#   'Mitsuokella sp. oral taxon 131 str. W9106',
#   'Phascolarctobacterium succinatutens YIT 12067',
#   'Pseudoleptotrichia goodfellowii F0264',
#   'Leptotrichia hofstadii F0254',
#   'Fusobacterium gonidiaformans 3-1-5R',
#   'Veillonella sp. HPA0037',
#   'Cetobacterium somerae ATCC BAA-474',
#   'Megasphaera vaginalis (ex Srinivasan et al. 2021)',
#   'Megasphaera elsdenii DSM 20460',
#   'Youngiibacter fragilis 232.1',
#   'Anaeroglobus geminatus F0357',
#   'Fusobacterium nucleatum subsp. nucleatum ATCC 25586',
#   'Veillonella sp. oral taxon 780 str. F0422',
#   'Sebaldella termitidis ATCC 33386'],
#  39: ['Megasphaera micronuciformis F0359',
#   'Tepidanaerobacter acetatoxydans Re1',
#   'Dialister succinatiphilus YIT 11850',
#   'Thermosediminibacter oceani DSM 16646',
#   'Halobacteroides halobius DSM 5150',
#   'Caldisalinibacter kiritimatiensis',
#   'Selenomonas sputigena ATCC 35185',
#   'Acetoanaerobium sticklandii DSM 519',
#   'Caldanaerobacter subterraneus subsp. tengcongensis MB4',
#   'Thermoanaerobacter pseudethanolicus ATCC 33223',
#   'Caloramator australicus RC3',
#   'Thermoanaerobacterium thermosaccharolyticum DSM 571',
#   'Acetohalobium arabaticum DSM 5501',
#   'Natranaerobius thermophilus JW/NM-WN-LF',
#   'Selenomonas sp. F0473',
#   'Thermobrachium celere DSM 8682'],
#  40: ['Sulfobacillus acidophilus DSM 10332',
#   'Thermobaculum terrenum ATCC BAA-798',
#   'Ktedonobacter racemifer DSM 44963'],
#  41: ['Lentilactobacillus buchneri subsp. silagei CD034',
#   'Loigolactobacillus coryniformis subsp. coryniformis CECT 5711',
#   'Fructilactobacillus sanfranciscensis TMW 1.1304',
#   'Ligilactobacillus ruminis ATCC 27782',
#   'Lactobacillus delbrueckii subsp. bulgaricus ATCC 11842 = JCM 1002',
#   'Lentilactobacillus hilgardii DSM 20176 = ATCC 8290',
#   'Streptococcus thermophilus LMG 18311',
#   'Streptococcus gordonii str. Challis substr. CH1',
#   'Limosilactobacillus coleohominis 101-4-CHN',
#   'Lactobacillus amylolyticus DSM 11664',
#   'Lactococcus cremoris subsp. cremoris TIFN6',
#   'Enterococcus sulfureus ATCC 49903',
#   'Lactobacillus iners DSM 13335',
#   'Catellicoccus marimammalium M35/04/3',
#   'Streptococcus intermedius B196',
#   'Vagococcus lutrae LBD1',
#   'Facklamia languida CCUG 37842',
#   'Streptococcus pneumoniae TIGR4',
#   'Streptococcus pneumoniae R6',
#   'Leuconostoc carnosum JB16',
#   'Lentilactobacillus parafarraginis F0439',
#   'Enterococcus cecorum DSM 20682 = ATCC 43198',
#   'Limosilactobacillus gastricus PS3',
#   'Streptococcus agalactiae 2603V/R',
#   'Lactobacillus acidophilus NCFM',
#   'Pediococcus acidilactici DSM 20284',
#   'Facklamia hominis CCUG 36813',
#   'Streptococcus pyogenes serotype M1',
#   'Oenococcus oeni PSU-1',
#   'Mycoplasmoides pneumoniae M129',
#   'Ligilactobacillus salivarius UCC118',
#   'Listeria monocytogenes EGD-e',
#   'Weissella paramesenteroides ATCC 33313',
#   'Lactobacillus pasteurii DSM 23907 = CRBIP 24.76',
#   'Alloiococcus otitis ATCC 51267',
#   'Streptococcus suis BM407',
#   'Lactococcus lactis subsp. lactis Il1403',
#   'Listeria grayi DSM 20601',
#   'Enterococcus italicus DSM 15952',
#   'Streptococcus sanguinis SK36',
#   'Streptococcus mutans UA159',
#   'Limosilactobacillus reuteri subsp. reuteri',
#   'Latilactobacillus sakei subsp. sakei 23K',
#   'Lactococcus garvieae Lg2',
#   'Melissococcus plutonius ATCC 35311',
#   'Streptococcus infantis ATCC 700779',
#   'Granulicatella elegans ATCC 700633',
#   'Carnobacterium sp. 17-4',
#   'Limosilactobacillus mucosae LM1',
#   'Enterococcus saccharolyticus subsp. saccharolyticus ATCC 43076',
#   'Enterococcus dispar ATCC 51266',
#   'Dolosigranulum pigrum ATCC 51524',
#   'Enterococcus columbae DSM 7374 = ATCC 51263',
#   'Enterococcus faecalis V583',
#   'Enterococcus phoeniculicola ATCC BAA-412',
#   'Enterococcus pallens ATCC BAA-351',
#   'Levilactobacillus brevis ATCC 367',
#   'Streptococcus ictaluri 707-05',
#   'Streptococcus pneumoniae D39',
#   'Enterococcus casseliflavus EC20',
#   'Streptococcus pasteurianus ATCC 43144',
#   'Ligilactobacillus saerimneri 30a',
#   'Aerococcus sp. Group 1',
#   'Erysipelothrix rhusiopathiae ATCC 19414',
#   'Lacticaseibacillus paracasei ATCC 334',
#   'Enterococcus asini ATCC 700915',
#   'Streptococcus uberis 0140J',
#   'Eremococcus coleocola ACS-139-V-Col8',
#   'Pediococcus claussenii ATCC BAA-344',
#   'Brochothrix campestris FSL F6-1037',
#   'Carnobacterium maltaromaticum LMA28',
#   'Granulicatella adiacens ATCC 49175',
#   'Oenococcus kitaharae DSM 17330',
#   'Lactiplantibacillus plantarum WCFS1',
#   'Falseniella ignava CCUG 37419',
#   'Abiotrophia defectiva ATCC 49176',
#   'Streptococcus urinalis 2285-97',
#   'Ligilactobacillus equi DPC 6820'],
#  42: ['Metapseudomonas resinovorans NBRC 106553',
#   'Pseudomonas sp. HPB0071',
#   'Pseudomonas syringae pv. tomato str. DC3000',
#   'Marinomonas mediterranea MMB-1',
#   'Stutzerimonas stutzeri A1501',
#   'Pseudogulbenkiania sp. NH8B',
#   'Hahella chejuensis KCTC 2396',
#   'Pseudomonas sp. M47T1',
#   'Pseudomonas fulva 12-X',
#   'Chromobacterium violaceum ATCC 12472',
#   'Pseudomonas putida KT2440',
#   'Pseudomonas aeruginosa PAO1'],
#  43: ['Granulicella mallensis MP5ACTX8',
#   'Terriglobus saanensis SP1PR4',
#   'Gemmatirosa kalamazoonensis',
#   'Candidatus Koribacter versatilis Ellin345',
#   'Acidobacterium capsulatum ATCC 51196',
#   'Terriglobus roseus DSM 18391',
#   'Nitrolancea hollandica Lb',
#   'Granulicella tundricola MP5ACTX9'],
#  44: ['Firmicutes bacterium M10-2',
#   'Atopobium minutum 10063974',
#   'candidate division TM7 genomosp. GTL1',
#   'Fannyhessea vaginae DSM 15829',
#   'Collinsella tanakaei YIT 12063',
#   'Coriobacteriaceae bacterium BV3Ac1',
#   'Candidatus Saccharibacteria bacterium RAAC3_TM7_1',
#   'Olsenella profusa F0195',
#   'Collinsella stercoris DSM 13279',
#   'Mycoplasma mycoides subsp. mycoides SC str. PG1',
#   'Solobacterium moorei F0204',
#   'Candidatus Saccharimonas aalborgensis',
#   'Lancefieldella parvula DSM 20469',
#   'Cryptobacterium curtum DSM 15641',
#   'Coriobacterium glomerans PW2',
#   'Bulleidia extructa W1219',
#   'Helcococcus kunzii ATCC 51366',
#   'Olsenella uli DSM 7084',
#   'Atopobium sp. oral taxon 199 str. F0494',
#   'Eggerthia catenaformis OT 569 = DSM 20559',
#   'Olsenella sp. oral taxon 809 str. F0356'],
#  45: ['Anaerococcus prevotii ACS-065-V-Col13',
#   'Anaerococcus lactolyticus ATCC 51172',
#   'Peptoniphilus indolicus ATCC 29427',
#   'Peptoanaerobacter stomatis',
#   'Peptoniphilus duerdenii ATCC BAA-1640',
#   'Peptostreptococcus stomatis DSM 17678',
#   'Eubacterium nodatum ATCC 33099',
#   'Peptacetobacter hiranonis DSM 13275',
#   'Clostridium sp. SY8519',
#   'Mogibacterium sp. CM50',
#   'Shuttleworthella satelles DSM 14600',
#   'Mageeibacillus indolicus UPII9-5',
#   'Peptostreptococcaceae bacterium oral taxon 113 str. W5053',
#   'Oribacterium sp. oral taxon 078 str. F0263',
#   'Pseudoramibacter alactolyticus ATCC 23263',
#   'Johnsonella ignava ATCC 51276',
#   'Peptoniphilus sp. oral taxon 386 str. F0131',
#   'Eubacterium infirmum F0142',
#   'Peptostreptococcaceae bacterium AS15',
#   'Peptoniphilus sp. BV3C26',
#   'Eubacterium brachy ATCC 33089',
#   'Eubacterium saphenum ATCC 49989',
#   'Peptoniphilus lacrimalis 315-B',
#   'Anaerococcus vaginalis ATCC 51170',
#   'Finegoldia magna ATCC 29328',
#   'Filifactor alocis ATCC 35896',
#   'Acholeplasma laidlawii PG-8A',
#   'Peptoniphilus harei ACS-146-V-Sch2b'],
#  46: ['Fervidobacterium nodosum Rt17-B1',
#   'Caldisericum exile AZM16c01',
#   'Caldicellulosiruptor owensensis OL',
#   'Kosmotoga olearia TBF 19.5.1',
#   'Dictyoglomus turgidum DSM 6724',
#   'Marinitoga piezophila KA3',
#   'Pseudothermotoga lettingae TMO',
#   'Mesotoga prima MesG1.Ag.4.2',
#   'Coprothermobacter proteolyticus DSM 5265',
#   'Thermotoga maritima MSB8',
#   'Halothermothrix orenii H 168'],
#  47: ['Rickettsia prowazekii str. Madrid E',
#   'Candidatus Blochmanniella pennsylvanica str. BPEN',
#   'Francisella tularensis subsp. tularensis SCHU S4',
#   'Eikenella corrodens CC92I',
#   'Candidatus Regiella insecticola 5.15',
#   'Serratia symbiotica str. Tucson',
#   'Candidatus Profftella armatura',
#   'Actinobacillus pleuropneumoniae serovar 5b str. L20',
#   'Oxalobacter formigenes OXCC13',
#   'Candidatus Carsonella ruddii HC isolate Thao2000',
#   'secondary endosymbiont of Ctenarytaina eucalypti',
#   'Neisseria sp. oral taxon 020 str. F0370',
#   'Dichelobacter nodosus VCS1703A',
#   'Candidatus Vesicomyidisocius calyptogenae',
#   'Buchnera aphidicola BCc',
#   'Actinobacillus succinogenes 130Z',
#   'Glaesserella parasuis SH0165',
#   'Sutterella parvirubra YIT 11816',
#   'Succinatimonas hippei YIT 12066',
#   'Kingella kingae ATCC 23330',
#   'Buchnera aphidicola str. Bp (Baizongia pistaciae)',
#   'Simonsiella muelleri ATCC 29453',
#   'Kingella denitrificans ATCC 33394',
#   '[Haemophilus] ducreyi 35000HP',
#   'Cardiobacterium hominis ATCC 15826',
#   'Wigglesworthia glossinidia endosymbiont of Glossina brevipalpis',
#   'Buchnera aphidicola (Cinara tujafilina)',
#   'Neisseria bacilliformis ATCC BAA-1200',
#   'Haemophilus influenzae Rd KW20',
#   'secondary endosymbiont of Heteropsylla cubana',
#   'Wolbachia endosymbiont of Onchocerca ochengi',
#   'Pasteurella bettyae CCUG 2042',
#   'Sutterella wadsworthensis HGA0223',
#   'Taylorella asinigenitalis MCE3',
#   'Thiomicrospira cyclica ALM1',
#   'Candidatus Regiella insecticola LSR1',
#   'Kingella oralis ATCC 51147',
#   'Pasteurella multocida subsp. multocida str. Pm70',
#   'Anaplasma marginale str. Florida',
#   'Candidatus Pantoea carbekii',
#   'Candidatus Zinderia insecticola CARI',
#   'Candidatus Kinetoplastidibacterium crithidiae TCC036E',
#   'Baumannia cicadellinicola str. Hc (Homalodisca coagulata)',
#   'Blattabacterium sp. (Periplaneta americana) str. BPLAN',
#   'Candidatus Moranella endobia PCIT',
#   'Neisseria shayeganii 871',
#   'Sutterella wadsworthensis 2_1_59BFAA',
#   'Ehrlichia chaffeensis str. Arkansas',
#   'Wohlfahrtiimonas chitiniclastica SH04',
#   'Candidatus Kinetoplastidibacterium blastocrithidiae TCC012E',
#   'Neisseria meningitidis MC58',
#   'Candidatus Uzinura diaspidicola str. ASNER',
#   'Buchnera aphidicola str. APS (Acyrthosiphon pisum)',
#   'Neisseria gonorrhoeae FA 1090']}

# %%
def index_tree(tree_dir: nx.DiGraph):
    # Find root (in-degree 0)
    roots = [v for v in tree_dir.nodes if tree_dir.in_degree(v) == 0]
    if len(roots) != 1:
        raise ValueError(f"Expected exactly one root, found {len(roots)}")
    root = roots[0]

    # Build parent/children
    parent = {root: None}
    children = {v: [] for v in tree_dir.nodes}
    for u, v in tree_dir.edges:
        parent[v] = u
        children[u].append(v)

    # Iterative DFS to get tin, depth, subtree_size
    tin, depth, subtree_size = {}, {}, {}
    node_by_tin = []
    t = 0
    depth[root] = 0
    stack = [(root, 0)]  # (node, 0=enter, 1=exit)
    while stack:
        v, state = stack.pop()
        if state == 0:
            tin[v] = t
            node_by_tin.append(v)
            t += 1
            stack.append((v, 1))
            # Push children in reverse so leftmost visits first
            for w in reversed(children[v]):
                depth[w] = depth[v] + 1
                stack.append((w, 0))
        else:
            s = 1
            for w in children[v]:
                s += subtree_size[w]
            subtree_size[v] = s

    tout = {v: tin[v] + subtree_size[v] - 1 for v in tree_dir.nodes}
    return {
        "root": root, "parent": parent, "children": children, "depth": depth,
        "tin": tin, "tout": tout, "subtree_size": subtree_size, "n": len(node_by_tin)
    }

def _normalize(u):
    # e.g. 795666.0 -> 795666
    return int(u) if isinstance(u, float) and u.is_integer() else u

def cluster_tree_stats(idx, cluster_nodes, alpha=0.8, size_cap=None):
    """
    Compute robust clade-based summaries for a cluster:
      - best coverage clade (max |C∩subtree(v)| / |C|)
      - best Jaccard clade ( |C∩S| / (|C| + |S| - |C∩S|) ) to penalize huge clades
      - alpha-majority clade: deepest v with |C∩subtree(v)| >= ceil(alpha*|C|)
    Optional: size_cap limits candidate clades to subtree_size(v) <= size_cap.
    """

    tin, tout, depth, parent, subtree_size = (idx["tin"], idx["tout"], idx["depth"], idx["parent"], idx["subtree_size"])

    C_all = list(cluster_nodes)	# list 
    C = [_normalize(u) for u in C_all if u in tin]  # filter to nodes present in this tree
    skipped = len(C_all) - len(C)
    if len(C) == 0:
        return {"n_in_cluster": 0, "n_skipped": skipped}

    # Pre-sort cluster members in preorder
    C_tins = sorted(tin[u] for u in C)

    def count_in_subtree(v):
        a, b = tin[v], tout[v]
        return bisect_right(C_tins, b) - bisect_left(C_tins, a)

    # Candidates = union of ancestors of the cluster (small)
    candidates = set()
    for u in C:
        v = u
        while v is not None and v not in candidates:
            if size_cap is None or subtree_size[v] <= size_cap:
                candidates.add(v)
            v = parent[v]

    best_cov_node, best_cov, best_cov_depth = None, -1, -1
    best_j_node, best_j, best_j_depth = None, -1.0, -1
    thr = math.ceil(alpha * len(C))
    alpha_node, alpha_cov, alpha_depth = None, 0, -1

    for v in candidates:
        cov = count_in_subtree(v)
        # 1) Best coverage (fraction of cluster captured)
        if cov > best_cov or (cov == best_cov and depth[v] > best_cov_depth):
            best_cov, best_cov_node, best_cov_depth = cov, v, depth[v]

        # 2) Best Jaccard (penalizes very big clades)
        j = cov / (len(C) + subtree_size[v] - cov)
        if j > best_j or (j == best_j and depth[v] > best_j_depth):
            best_j, best_j_node, best_j_depth = j, v, depth[v]

        # 3) α-majority clade (deepest node capturing >= α of the cluster)
        if cov >= thr and depth[v] > alpha_depth:
            alpha_node, alpha_cov, alpha_depth = v, cov, depth[v]

    result = {
        "n_in_cluster": len(C),
        "n_skipped": skipped,
        "best_coverage_node": best_cov_node,
        "best_coverage_fraction": best_cov / len(C),
        "best_coverage_subtree_size": subtree_size[best_cov_node] if best_cov_node else None,
        "best_jaccard_node": best_j_node,
        "best_jaccard": best_j,
        "best_jaccard_subtree_size": subtree_size[best_j_node] if best_j_node else None,
        "alpha": alpha,
        "alpha_node": alpha_node,
        "alpha_fraction": (alpha_cov / len(C)) if alpha_node else 0.0,
        "alpha_subtree_size": subtree_size[alpha_node] if alpha_node else None,
        "alpha_outliers": (len(C) - alpha_cov) if alpha_node else len(C) - best_cov,
    }
    return result

def cluster_core_and_outliers(idx, cluster_nodes, chosen_node):
    """Split a cluster into the core inside chosen_node's subtree and the outliers."""
    if chosen_node is None:
        return [], list(cluster_nodes)
    tin, tout = idx["tin"], idx["tout"]
    a, b = tin[chosen_node], tout[chosen_node]
    core, out = [], []
    for u in cluster_nodes:
        u2 = _normalize(u)
        if u2 in tin and a <= tin[u2] <= b:
            core.append(u)
        else:
            out.append(u)
    return core, out

# %%
idx = index_tree(tree_dir)

# %%
def fmt_node(node, tid2nm):
    """Format a node as 'taxid [name]' if name exists; handle None."""
    if node is None:
        return "None"
    name = tid2nm.get(node)
    return f"{node} [{name}]" if name else str(node)

def summarize_clusters(idx, clusters, tid2nm, alpha=0.75, size_cap=None, show_all=False):
    """
    Print a compact summary per cluster with translated node labels in brackets.
    Set show_all=True to also dump the full stats dict.
    """
    n_clusters = len(clusters)
    for i, C in enumerate(clusters, 1):
        stats = cluster_tree_stats(idx, C, alpha=alpha, size_cap=size_cap)
        rep = stats.get("alpha_node") or stats.get("best_jaccard_node")
        core, outliers = cluster_core_and_outliers(idx, C, rep)

        ac = stats.get  # tiny shortcut

        print(f"Cluster {i}/{n_clusters}")
        print(f"  in_tree={ac('n_in_cluster',0)}  skipped={ac('n_skipped',0)}")

        # Majority (alpha) clade
        print(f"  Majority α={ac('alpha')}: {fmt_node(ac('alpha_node'), tid2nm)}  "
              f"frac={ac('alpha_fraction',0):.3f}  size={ac('alpha_subtree_size')}")

        # Best coverage clade
        print(f"  Best coverage: {fmt_node(ac('best_coverage_node'), tid2nm)}  "
              f"frac={ac('best_coverage_fraction',0):.3f}  "
              f"size={ac('best_coverage_subtree_size')}")

        # Best Jaccard clade
        print(f"  Best Jaccard: {fmt_node(ac('best_jaccard_node'), tid2nm)}  "
              f"J={ac('best_jaccard',0):.3f}  size={ac('best_jaccard_subtree_size')}")

        # Representative clade (alpha if present, else best Jaccard)
        print(f"  Representative clade: {fmt_node(rep, tid2nm)}")

        print(f"  Core={len(core)}  Outliers={len(outliers)}")
        if show_all:
            for k, v in stats.items():
                print(f"    {k}: {v}")
        print()
        
summarize_clusters(idx, clusters.values(), tid2nm, alpha=0.75, size_cap=None, show_all=True)
# Out:
# Cluster 1/48
#   in_tree=42  skipped=0
#   Majority α=0.75: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 64898 [Aquificaceae]  J=0.033  size=114
#   Representative clade: 3379134 [Pseudomonadati]
#   Core=42  Outliers=0
#     n_in_cluster: 42
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 64898
#     best_jaccard: 0.033112582781456956
#     best_jaccard_subtree_size: 114
#     alpha: 0.75
#     alpha_node: 3379134
#     alpha_fraction: 1.0
#     alpha_subtree_size: 290974
#     alpha_outliers: 0
#
# Cluster 2/48
#   in_tree=31  skipped=0
#   Majority α=0.75: 356 [Hyphomicrobiales]  frac=0.871  size=36655
#   Best coverage: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best Jaccard: 176299 [Agrobacterium fabrum str. C58]  J=0.032  size=1
#   Representative clade: 356 [Hyphomicrobiales]
#   Core=27  Outliers=4
#     n_in_cluster: 31
#     n_skipped: 0
#     best_coverage_node: 28211
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 71591
#     best_jaccard_node: 176299
#     best_jaccard: 0.03225806451612903
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 356
#     alpha_fraction: 0.8709677419354839
#     alpha_subtree_size: 36655
#     alpha_outliers: 4
#
# Cluster 3/48
#   in_tree=40  skipped=0
#   Majority α=0.75: 186801 [Clostridia]  frac=0.975  size=13369
#   Best coverage: 1239 [Bacillota]  frac=1.000  size=94865
#   Best Jaccard: 478749 [Marvinbryantia formatexigens DSM 14469]  J=0.025  size=1
#   Representative clade: 186801 [Clostridia]
#   Core=39  Outliers=1
#     n_in_cluster: 40
#     n_skipped: 0
#     best_coverage_node: 1239
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 94865
#     best_jaccard_node: 478749
#     best_jaccard: 0.025
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 186801
#     alpha_fraction: 0.975
#     alpha_subtree_size: 13369
#     alpha_outliers: 1
#
# Cluster 4/48
#   in_tree=22  skipped=0
#   Majority α=0.75: 3028117 [Cyanophyceae]  frac=1.000  size=34280
#   Best coverage: 3028117 [Cyanophyceae]  frac=1.000  size=34280
#   Best Jaccard: 1111708 [Synechocystis sp. PCC 6803 substr. Kazusa]  J=0.045  size=1
#   Representative clade: 3028117 [Cyanophyceae]
#   Core=22  Outliers=0
#     n_in_cluster: 22
#     n_skipped: 0
#     best_coverage_node: 3028117
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 34280
#     best_jaccard_node: 1111708
#     best_jaccard: 0.045454545454545456
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 3028117
#     alpha_fraction: 1.0
#     alpha_subtree_size: 34280
#     alpha_outliers: 0
#
# Cluster 5/48
#   in_tree=52  skipped=0
#   Majority α=0.75: 171549 [Bacteroidales]  frac=0.962  size=4465
#   Best coverage: 976 [Bacteroidota]  frac=1.000  size=25950
#   Best Jaccard: 2974251 [Segatella]  J=0.077  size=46
#   Representative clade: 171549 [Bacteroidales]
#   Core=50  Outliers=2
#     n_in_cluster: 52
#     n_skipped: 0
#     best_coverage_node: 976
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 25950
#     best_jaccard_node: 2974251
#     best_jaccard: 0.07692307692307693
#     best_jaccard_subtree_size: 46
#     alpha: 0.75
#     alpha_node: 171549
#     alpha_fraction: 0.9615384615384616
#     alpha_subtree_size: 4465
#     alpha_outliers: 2
#
# Cluster 6/48
#   in_tree=35  skipped=0
#   Majority α=0.75: 85007 [Mycobacteriales]  frac=0.886  size=15482
#   Best coverage: 201174 [Actinomycetota]  frac=1.000  size=96386
#   Best Jaccard: 286801 [Segniliparus]  J=0.048  size=9
#   Representative clade: 85007 [Mycobacteriales]
#   Core=31  Outliers=4
#     n_in_cluster: 35
#     n_skipped: 0
#     best_coverage_node: 201174
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 96386
#     best_jaccard_node: 286801
#     best_jaccard: 0.047619047619047616
#     best_jaccard_subtree_size: 9
#     alpha: 0.75
#     alpha_node: 85007
#     alpha_fraction: 0.8857142857142857
#     alpha_subtree_size: 15482
#     alpha_outliers: 4
#
# Cluster 7/48
#   in_tree=13  skipped=0
#   Majority α=0.75: 1236 [Gammaproteobacteria]  frac=0.769  size=137913
#   Best coverage: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best Jaccard: 871585 [Acinetobacter pittii PHEA-2]  J=0.077  size=1
#   Representative clade: 1236 [Gammaproteobacteria]
#   Core=10  Outliers=3
#     n_in_cluster: 13
#     n_skipped: 0
#     best_coverage_node: 1224
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 241984
#     best_jaccard_node: 871585
#     best_jaccard: 0.07692307692307693
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1236
#     alpha_fraction: 0.7692307692307693
#     alpha_subtree_size: 137913
#     alpha_outliers: 3
#
# Cluster 8/48
#   in_tree=39  skipped=0
#   Majority α=0.75: 1760 [Actinomycetes]  frac=0.897  size=93756
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 85018 [Dermatophilaceae]  J=0.029  size=69
#   Representative clade: 1760 [Actinomycetes]
#   Core=35  Outliers=4
#     n_in_cluster: 39
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 85018
#     best_jaccard: 0.02857142857142857
#     best_jaccard_subtree_size: 69
#     alpha: 0.75
#     alpha_node: 1760
#     alpha_fraction: 0.8974358974358975
#     alpha_subtree_size: 93756
#     alpha_outliers: 4
#
# Cluster 9/48
#   in_tree=13  skipped=0
#   Majority α=0.75: 2 [Bacteria]  frac=1.000  size=594260
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 1293054 [Halanaerobium saccharolyticum subsp. saccharolyticum DSM 6643]  J=0.077  size=1
#   Representative clade: 2 [Bacteria]
#   Core=13  Outliers=0
#     n_in_cluster: 13
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 1293054
#     best_jaccard: 0.07692307692307693
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 2
#     alpha_fraction: 1.0
#     alpha_subtree_size: 594260
#     alpha_outliers: 0
#
# Cluster 10/48
#   in_tree=20  skipped=0
#   Majority α=0.75: 1236 [Gammaproteobacteria]  frac=0.800  size=137913
#   Best coverage: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best Jaccard: 391936 [Isoalcanivorax pacificus W11-5]  J=0.050  size=1
#   Representative clade: 1236 [Gammaproteobacteria]
#   Core=16  Outliers=4
#     n_in_cluster: 20
#     n_skipped: 0
#     best_coverage_node: 1224
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 241984
#     best_jaccard_node: 391936
#     best_jaccard: 0.05
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1236
#     alpha_fraction: 0.8
#     alpha_subtree_size: 137913
#     alpha_outliers: 4
#
# Cluster 11/48
#   in_tree=13  skipped=0
#   Majority α=0.75: 186802 [Eubacteriales]  frac=0.769  size=7979
#   Best coverage: 186801 [Clostridia]  frac=1.000  size=13369
#   Best Jaccard: 1121335 [Thermoclostridium stercorarium subsp. stercorarium DSM 8532]  J=0.077  size=1
#   Representative clade: 186802 [Eubacteriales]
#   Core=10  Outliers=3
#     n_in_cluster: 13
#     n_skipped: 0
#     best_coverage_node: 186801
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 13369
#     best_jaccard_node: 1121335
#     best_jaccard: 0.07692307692307693
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 186802
#     alpha_fraction: 0.7692307692307693
#     alpha_subtree_size: 7979
#     alpha_outliers: 3
#
# Cluster 12/48
#   in_tree=46  skipped=0
#   Majority α=0.75: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best coverage: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best Jaccard: 1227 [Nitrosococcus]  J=0.033  size=16
#   Representative clade: 1224 [Pseudomonadota]
#   Core=46  Outliers=0
#     n_in_cluster: 46
#     n_skipped: 0
#     best_coverage_node: 1224
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 241984
#     best_jaccard_node: 1227
#     best_jaccard: 0.03333333333333333
#     best_jaccard_subtree_size: 16
#     alpha: 0.75
#     alpha_node: 1224
#     alpha_fraction: 1.0
#     alpha_subtree_size: 241984
#     alpha_outliers: 0
#
# Cluster 13/48
#   in_tree=34  skipped=0
#   Majority α=0.75: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best coverage: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best Jaccard: 155892 [Caulobacter vibrioides]  J=0.056  size=4
#   Representative clade: 1224 [Pseudomonadota]
#   Core=34  Outliers=0
#     n_in_cluster: 34
#     n_skipped: 0
#     best_coverage_node: 1224
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 241984
#     best_jaccard_node: 155892
#     best_jaccard: 0.05555555555555555
#     best_jaccard_subtree_size: 4
#     alpha: 0.75
#     alpha_node: 1224
#     alpha_fraction: 1.0
#     alpha_subtree_size: 241984
#     alpha_outliers: 0
#
# Cluster 14/48
#   in_tree=40  skipped=0
#   Majority α=0.75: 1236 [Gammaproteobacteria]  frac=1.000  size=137913
#   Best coverage: 1236 [Gammaproteobacteria]  frac=1.000  size=137913
#   Best Jaccard: 1621534 [Paraglaciecola]  J=0.029  size=32
#   Representative clade: 1236 [Gammaproteobacteria]
#   Core=40  Outliers=0
#     n_in_cluster: 40
#     n_skipped: 0
#     best_coverage_node: 1236
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 137913
#     best_jaccard_node: 1621534
#     best_jaccard: 0.02857142857142857
#     best_jaccard_subtree_size: 32
#     alpha: 0.75
#     alpha_node: 1236
#     alpha_fraction: 1.0
#     alpha_subtree_size: 137913
#     alpha_outliers: 0
#
# Cluster 15/48
#   in_tree=12  skipped=0
#   Majority α=0.75: 186822 [Paenibacillaceae]  frac=0.917  size=6575
#   Best coverage: 1385 [Bacillales]  frac=1.000  size=62961
#   Best Jaccard: 621372 [Paenibacillus sp. oral taxon 786 str. D14]  J=0.083  size=1
#   Representative clade: 186822 [Paenibacillaceae]
#   Core=11  Outliers=1
#     n_in_cluster: 12
#     n_skipped: 0
#     best_coverage_node: 1385
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 62961
#     best_jaccard_node: 621372
#     best_jaccard: 0.08333333333333333
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 186822
#     alpha_fraction: 0.9166666666666666
#     alpha_subtree_size: 6575
#     alpha_outliers: 1
#
# Cluster 16/48
#   in_tree=48  skipped=0
#   Majority α=0.75: 1760 [Actinomycetes]  frac=1.000  size=93756
#   Best coverage: 1760 [Actinomycetes]  frac=1.000  size=93756
#   Best Jaccard: 2838335 [Streptomyces aurantiacus group]  J=0.031  size=19
#   Representative clade: 1760 [Actinomycetes]
#   Core=48  Outliers=0
#     n_in_cluster: 48
#     n_skipped: 0
#     best_coverage_node: 1760
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 93756
#     best_jaccard_node: 2838335
#     best_jaccard: 0.03076923076923077
#     best_jaccard_subtree_size: 19
#     alpha: 0.75
#     alpha_node: 1760
#     alpha_fraction: 1.0
#     alpha_subtree_size: 93756
#     alpha_outliers: 0
#
# Cluster 17/48
#   in_tree=72  skipped=0
#   Majority α=0.75: 976 [Bacteroidota]  frac=0.986  size=25950
#   Best coverage: 68336 [Bacteroidota/Chlorobiota group]  frac=1.000  size=26794
#   Best Jaccard: 379068 [Galbibacter]  J=0.022  size=20
#   Representative clade: 976 [Bacteroidota]
#   Core=71  Outliers=1
#     n_in_cluster: 72
#     n_skipped: 0
#     best_coverage_node: 68336
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 26794
#     best_jaccard_node: 379068
#     best_jaccard: 0.022222222222222223
#     best_jaccard_subtree_size: 20
#     alpha: 0.75
#     alpha_node: 976
#     alpha_fraction: 0.9861111111111112
#     alpha_subtree_size: 25950
#     alpha_outliers: 1
#
# Cluster 18/48
#   in_tree=42  skipped=0
#   Majority α=0.75: 1385 [Bacillales]  frac=0.976  size=62961
#   Best coverage: 1239 [Bacillota]  frac=1.000  size=94865
#   Best Jaccard: 2893056 [Halalkalibacter]  J=0.032  size=23
#   Representative clade: 1385 [Bacillales]
#   Core=41  Outliers=1
#     n_in_cluster: 42
#     n_skipped: 0
#     best_coverage_node: 1239
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 94865
#     best_jaccard_node: 2893056
#     best_jaccard: 0.031746031746031744
#     best_jaccard_subtree_size: 23
#     alpha: 0.75
#     alpha_node: 1385
#     alpha_fraction: 0.9761904761904762
#     alpha_subtree_size: 62961
#     alpha_outliers: 1
#
# Cluster 19/48
#   in_tree=29  skipped=0
#   Majority α=0.75: 3379134 [Pseudomonadati]  frac=0.966  size=290974
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 272561 [Chlamydia trachomatis D/UW-3/CX]  J=0.034  size=1
#   Representative clade: 3379134 [Pseudomonadati]
#   Core=28  Outliers=1
#     n_in_cluster: 29
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 272561
#     best_jaccard: 0.034482758620689655
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 3379134
#     alpha_fraction: 0.9655172413793104
#     alpha_subtree_size: 290974
#     alpha_outliers: 1
#
# Cluster 20/48
#   in_tree=23  skipped=1
#   Majority α=0.75: 80840 [Burkholderiales]  frac=1.000  size=23982
#   Best coverage: 80840 [Burkholderiales]  frac=1.000  size=23982
#   Best Jaccard: 395019 [Burkholderia multivorans ATCC 17616]  J=0.043  size=1
#   Representative clade: 80840 [Burkholderiales]
#   Core=23  Outliers=1
#     n_in_cluster: 23
#     n_skipped: 1
#     best_coverage_node: 80840
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 23982
#     best_jaccard_node: 395019
#     best_jaccard: 0.043478260869565216
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 80840
#     alpha_fraction: 1.0
#     alpha_subtree_size: 23982
#     alpha_outliers: 0
#
# Cluster 21/48
#   in_tree=39  skipped=0
#   Majority α=0.75: 3028117 [Cyanophyceae]  frac=1.000  size=34280
#   Best coverage: 3028117 [Cyanophyceae]  frac=1.000  size=34280
#   Best Jaccard: 33071 [Gloeobacter]  J=0.033  size=24
#   Representative clade: 3028117 [Cyanophyceae]
#   Core=39  Outliers=0
#     n_in_cluster: 39
#     n_skipped: 0
#     best_coverage_node: 3028117
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 34280
#     best_jaccard_node: 33071
#     best_jaccard: 0.03278688524590164
#     best_jaccard_subtree_size: 24
#     alpha: 0.75
#     alpha_node: 3028117
#     alpha_fraction: 1.0
#     alpha_subtree_size: 34280
#     alpha_outliers: 0
#
# Cluster 22/48
#   in_tree=4  skipped=0
#   Majority α=0.75: 3031711 [Polyangia]  frac=0.750  size=311
#   Best coverage: 2818505 [Myxococcota]  frac=1.000  size=1107
#   Best Jaccard: 246197 [Myxococcus xanthus DK 1622]  J=0.250  size=1
#   Representative clade: 3031711 [Polyangia]
#   Core=3  Outliers=1
#     n_in_cluster: 4
#     n_skipped: 0
#     best_coverage_node: 2818505
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 1107
#     best_jaccard_node: 246197
#     best_jaccard: 0.25
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 3031711
#     alpha_fraction: 0.75
#     alpha_subtree_size: 311
#     alpha_outliers: 1
#
# Cluster 23/48
#   in_tree=45  skipped=0
#   Majority α=0.75: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best coverage: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best Jaccard: 359391 [Brucella abortus 2308]  J=0.022  size=1
#   Representative clade: 28211 [Alphaproteobacteria]
#   Core=45  Outliers=0
#     n_in_cluster: 45
#     n_skipped: 0
#     best_coverage_node: 28211
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 71591
#     best_jaccard_node: 359391
#     best_jaccard: 0.022222222222222223
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 28211
#     alpha_fraction: 1.0
#     alpha_subtree_size: 71591
#     alpha_outliers: 0
#
# Cluster 24/48
#   in_tree=10  skipped=0
#   Majority α=0.75: 203683 [Planctomycetia]  frac=0.800  size=1101
#   Best coverage: 1783257 [PVC group]  frac=1.000  size=4702
#   Best Jaccard: 530564 [Pirellula staleyi DSM 6068]  J=0.100  size=1
#   Representative clade: 203683 [Planctomycetia]
#   Core=8  Outliers=2
#     n_in_cluster: 10
#     n_skipped: 0
#     best_coverage_node: 1783257
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 4702
#     best_jaccard_node: 530564
#     best_jaccard: 0.1
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 203683
#     alpha_fraction: 0.8
#     alpha_subtree_size: 1101
#     alpha_outliers: 2
#
# Cluster 25/48
#   in_tree=36  skipped=0
#   Majority α=0.75: 544448 [Mycoplasmatota]  frac=1.000  size=4258
#   Best coverage: 544448 [Mycoplasmatota]  frac=1.000  size=4258
#   Best Jaccard: 2895623 [Metamycoplasmataceae]  J=0.075  size=180
#   Representative clade: 544448 [Mycoplasmatota]
#   Core=36  Outliers=0
#     n_in_cluster: 36
#     n_skipped: 0
#     best_coverage_node: 544448
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 4258
#     best_jaccard_node: 2895623
#     best_jaccard: 0.07462686567164178
#     best_jaccard_subtree_size: 180
#     alpha: 0.75
#     alpha_node: 544448
#     alpha_fraction: 1.0
#     alpha_subtree_size: 4258
#     alpha_outliers: 0
#
# Cluster 26/48
#   in_tree=18  skipped=0
#   Majority α=0.75: 28216 [Betaproteobacteria]  frac=0.889  size=31013
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 1088540 [Leptospira weilii serovar Topaz str. LT2116]  J=0.056  size=1
#   Representative clade: 28216 [Betaproteobacteria]
#   Core=16  Outliers=2
#     n_in_cluster: 18
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 1088540
#     best_jaccard: 0.05555555555555555
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 28216
#     alpha_fraction: 0.8888888888888888
#     alpha_subtree_size: 31013
#     alpha_outliers: 2
#
# Cluster 27/48
#   in_tree=11  skipped=0
#   Majority α=0.75: 3379134 [Pseudomonadati]  frac=0.909  size=290974
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 309807 [Salinibacter ruber DSM 13855]  J=0.091  size=1
#   Representative clade: 3379134 [Pseudomonadati]
#   Core=10  Outliers=1
#     n_in_cluster: 11
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 309807
#     best_jaccard: 0.09090909090909091
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 3379134
#     alpha_fraction: 0.9090909090909091
#     alpha_subtree_size: 290974
#     alpha_outliers: 1
#
# Cluster 28/48
#   in_tree=48  skipped=0
#   Majority α=0.75: 200940 [Thermodesulfobacteriota]  frac=0.833  size=3185
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 2910589 [Geotalea]  J=0.034  size=12
#   Representative clade: 200940 [Thermodesulfobacteriota]
#   Core=40  Outliers=8
#     n_in_cluster: 48
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 2910589
#     best_jaccard: 0.034482758620689655
#     best_jaccard_subtree_size: 12
#     alpha: 0.75
#     alpha_node: 200940
#     alpha_fraction: 0.8333333333333334
#     alpha_subtree_size: 3185
#     alpha_outliers: 8
#
# Cluster 29/48
#   in_tree=14  skipped=0
#   Majority α=0.75: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 1099 [Pelodictyon]  J=0.091  size=10
#   Representative clade: 3379134 [Pseudomonadati]
#   Core=14  Outliers=0
#     n_in_cluster: 14
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 1099
#     best_jaccard: 0.09090909090909091
#     best_jaccard_subtree_size: 10
#     alpha: 0.75
#     alpha_node: 3379134
#     alpha_fraction: 1.0
#     alpha_subtree_size: 290974
#     alpha_outliers: 0
#
# Cluster 30/48
#   in_tree=7  skipped=0
#   Majority α=0.75: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 320771 [Pedosphaera parvula Ellin514]  J=0.143  size=1
#   Representative clade: 3379134 [Pseudomonadati]
#   Core=7  Outliers=0
#     n_in_cluster: 7
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 320771
#     best_jaccard: 0.14285714285714285
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 3379134
#     alpha_fraction: 1.0
#     alpha_subtree_size: 290974
#     alpha_outliers: 0
#
# Cluster 31/48
#   in_tree=35  skipped=0
#   Majority α=0.75: 1239 [Bacillota]  frac=0.771  size=94865
#   Best coverage: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best Jaccard: 2916693 [Desulforamulus]  J=0.061  size=17
#   Representative clade: 1239 [Bacillota]
#   Core=27  Outliers=8
#     n_in_cluster: 35
#     n_skipped: 0
#     best_coverage_node: 1783272
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 233820
#     best_jaccard_node: 2916693
#     best_jaccard: 0.061224489795918366
#     best_jaccard_subtree_size: 17
#     alpha: 0.75
#     alpha_node: 1239
#     alpha_fraction: 0.7714285714285715
#     alpha_subtree_size: 94865
#     alpha_outliers: 8
#
# Cluster 32/48
#   in_tree=27  skipped=0
#   Majority α=0.75: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best coverage: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best Jaccard: 264203 [Zymomonas mobilis subsp. mobilis ZM4 = ATCC 31821]  J=0.037  size=1
#   Representative clade: 28211 [Alphaproteobacteria]
#   Core=27  Outliers=0
#     n_in_cluster: 27
#     n_skipped: 0
#     best_coverage_node: 28211
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 71591
#     best_jaccard_node: 264203
#     best_jaccard: 0.037037037037037035
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 28211
#     alpha_fraction: 1.0
#     alpha_subtree_size: 71591
#     alpha_outliers: 0
#
# Cluster 33/48
#   in_tree=20  skipped=0
#   Majority α=0.75: 136 [Spirochaetales]  frac=0.900  size=2082
#   Best coverage: 203692 [Spirochaetia]  frac=1.000  size=3782
#   Best Jaccard: 2951104 [Breznakiellaceae]  J=0.056  size=18
#   Representative clade: 136 [Spirochaetales]
#   Core=18  Outliers=2
#     n_in_cluster: 20
#     n_skipped: 0
#     best_coverage_node: 203692
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 3782
#     best_jaccard_node: 2951104
#     best_jaccard: 0.05555555555555555
#     best_jaccard_subtree_size: 18
#     alpha: 0.75
#     alpha_node: 136
#     alpha_fraction: 0.9
#     alpha_subtree_size: 2082
#     alpha_outliers: 2
#
# Cluster 34/48
#   in_tree=40  skipped=0
#   Majority α=0.75: 91347 [Enterobacterales]  frac=1.000  size=39984
#   Best coverage: 91347 [Enterobacterales]  frac=1.000  size=39984
#   Best Jaccard: 1125630 [Klebsiella pneumoniae subsp. pneumoniae HS11286]  J=0.025  size=1
#   Representative clade: 91347 [Enterobacterales]
#   Core=40  Outliers=0
#     n_in_cluster: 40
#     n_skipped: 0
#     best_coverage_node: 91347
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 39984
#     best_jaccard_node: 1125630
#     best_jaccard: 0.025
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 91347
#     alpha_fraction: 1.0
#     alpha_subtree_size: 39984
#     alpha_outliers: 0
#
# Cluster 35/48
#   in_tree=32  skipped=0
#   Majority α=0.75: 186801 [Clostridia]  frac=0.750  size=13369
#   Best coverage: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best Jaccard: 441771 [Clostridium botulinum A str. Hall]  J=0.031  size=1
#   Representative clade: 186801 [Clostridia]
#   Core=24  Outliers=8
#     n_in_cluster: 32
#     n_skipped: 0
#     best_coverage_node: 1783272
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 233820
#     best_jaccard_node: 441771
#     best_jaccard: 0.03125
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 186801
#     alpha_fraction: 0.75
#     alpha_subtree_size: 13369
#     alpha_outliers: 8
#
# Cluster 36/48
#   in_tree=57  skipped=0
#   Majority α=0.75: 1760 [Actinomycetes]  frac=1.000  size=93756
#   Best coverage: 1760 [Actinomycetes]  frac=1.000  size=93756
#   Best Jaccard: 196081 [Scardovia]  J=0.029  size=13
#   Representative clade: 1760 [Actinomycetes]
#   Core=57  Outliers=0
#     n_in_cluster: 57
#     n_skipped: 0
#     best_coverage_node: 1760
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 93756
#     best_jaccard_node: 196081
#     best_jaccard: 0.029411764705882353
#     best_jaccard_subtree_size: 13
#     alpha: 0.75
#     alpha_node: 1760
#     alpha_fraction: 1.0
#     alpha_subtree_size: 93756
#     alpha_outliers: 0
#
# Cluster 37/48
#   in_tree=15  skipped=0
#   Majority α=0.75: 2 [Bacteria]  frac=1.000  size=594260
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 479434 [Sphaerobacter thermophilus DSM 20745]  J=0.067  size=1
#   Representative clade: 2 [Bacteria]
#   Core=15  Outliers=0
#     n_in_cluster: 15
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 479434
#     best_jaccard: 0.06666666666666667
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 2
#     alpha_fraction: 1.0
#     alpha_subtree_size: 594260
#     alpha_outliers: 0
#
# Cluster 38/48
#   in_tree=27  skipped=0
#   Majority α=0.75: 204457 [Sphingomonadales]  frac=0.889  size=8227
#   Best coverage: 28211 [Alphaproteobacteria]  frac=1.000  size=71591
#   Best Jaccard: 332055 [Sphingobium indicum]  J=0.065  size=6
#   Representative clade: 204457 [Sphingomonadales]
#   Core=24  Outliers=3
#     n_in_cluster: 27
#     n_skipped: 0
#     best_coverage_node: 28211
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 71591
#     best_jaccard_node: 332055
#     best_jaccard: 0.06451612903225806
#     best_jaccard_subtree_size: 6
#     alpha: 0.75
#     alpha_node: 204457
#     alpha_fraction: 0.8888888888888888
#     alpha_subtree_size: 8227
#     alpha_outliers: 3
#
# Cluster 39/48
#   in_tree=19  skipped=0
#   Majority α=0.75: 2 [Bacteria]  frac=1.000  size=594260
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 1321779 [Leptotrichia sp. oral taxon 215 str. W9775]  J=0.053  size=1
#   Representative clade: 2 [Bacteria]
#   Core=19  Outliers=0
#     n_in_cluster: 19
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 1321779
#     best_jaccard: 0.05263157894736842
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 2
#     alpha_fraction: 1.0
#     alpha_subtree_size: 594260
#     alpha_outliers: 0
#
# Cluster 40/48
#   in_tree=16  skipped=0
#   Majority α=0.75: 1239 [Bacillota]  frac=1.000  size=94865
#   Best coverage: 1239 [Bacillota]  frac=1.000  size=94865
#   Best Jaccard: 273068 [Caldanaerobacter subterraneus subsp. tengcongensis MB4]  J=0.062  size=1
#   Representative clade: 1239 [Bacillota]
#   Core=16  Outliers=0
#     n_in_cluster: 16
#     n_skipped: 0
#     best_coverage_node: 1239
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 94865
#     best_jaccard_node: 273068
#     best_jaccard: 0.0625
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1239
#     alpha_fraction: 1.0
#     alpha_subtree_size: 94865
#     alpha_outliers: 0
#
# Cluster 41/48
#   in_tree=3  skipped=0
#   Majority α=0.75: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best coverage: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best Jaccard: 679936 [Sulfobacillus acidophilus DSM 10332]  J=0.333  size=1
#   Representative clade: 1783272 [Bacillati]
#   Core=3  Outliers=0
#     n_in_cluster: 3
#     n_skipped: 0
#     best_coverage_node: 1783272
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 233820
#     best_jaccard_node: 679936
#     best_jaccard: 0.3333333333333333
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1783272
#     alpha_fraction: 1.0
#     alpha_subtree_size: 233820
#     alpha_outliers: 0
#
# Cluster 42/48
#   in_tree=78  skipped=0
#   Majority α=0.75: 186826 [Lactobacillales]  frac=0.936  size=13989
#   Best coverage: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best Jaccard: 2767887 [Ligilactobacillus]  J=0.027  size=74
#   Representative clade: 186826 [Lactobacillales]
#   Core=73  Outliers=5
#     n_in_cluster: 78
#     n_skipped: 0
#     best_coverage_node: 1783272
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 233820
#     best_jaccard_node: 2767887
#     best_jaccard: 0.02702702702702703
#     best_jaccard_subtree_size: 74
#     alpha: 0.75
#     alpha_node: 186826
#     alpha_fraction: 0.9358974358974359
#     alpha_subtree_size: 13989
#     alpha_outliers: 5
#
# Cluster 43/48
#   in_tree=12  skipped=0
#   Majority α=0.75: 1236 [Gammaproteobacteria]  frac=0.833  size=137913
#   Best coverage: 1224 [Pseudomonadota]  frac=1.000  size=241984
#   Best Jaccard: 223283 [Pseudomonas syringae pv. tomato str. DC3000]  J=0.083  size=1
#   Representative clade: 1236 [Gammaproteobacteria]
#   Core=10  Outliers=2
#     n_in_cluster: 12
#     n_skipped: 0
#     best_coverage_node: 1224
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 241984
#     best_jaccard_node: 223283
#     best_jaccard: 0.08333333333333333
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1236
#     alpha_fraction: 0.8333333333333334
#     alpha_subtree_size: 137913
#     alpha_outliers: 2
#
# Cluster 44/48
#   in_tree=8  skipped=0
#   Majority α=0.75: 204433 [Terriglobales]  frac=0.750  size=421
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 1129897 [Nitrolancea hollandica Lb]  J=0.125  size=1
#   Representative clade: 204433 [Terriglobales]
#   Core=6  Outliers=2
#     n_in_cluster: 8
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 1129897
#     best_jaccard: 0.125
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 204433
#     alpha_fraction: 0.75
#     alpha_subtree_size: 421
#     alpha_outliers: 2
#
# Cluster 45/48
#   in_tree=21  skipped=0
#   Majority α=0.75: 1783272 [Bacillati]  frac=0.857  size=233820
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 272632 [Mycoplasma mycoides subsp. mycoides SC str. PG1]  J=0.048  size=1
#   Representative clade: 1783272 [Bacillati]
#   Core=18  Outliers=3
#     n_in_cluster: 21
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 272632
#     best_jaccard: 0.047619047619047616
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 1783272
#     alpha_fraction: 0.8571428571428571
#     alpha_subtree_size: 233820
#     alpha_outliers: 3
#
# Cluster 46/48
#   in_tree=28  skipped=0
#   Majority α=0.75: 1239 [Bacillota]  frac=0.964  size=94865
#   Best coverage: 1783272 [Bacillati]  frac=1.000  size=233820
#   Best Jaccard: 3106714 [unclassified Anaerovoracaceae Incertae Sedis]  J=0.085  size=23
#   Representative clade: 1239 [Bacillota]
#   Core=27  Outliers=1
#     n_in_cluster: 28
#     n_skipped: 0
#     best_coverage_node: 1783272
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 233820
#     best_jaccard_node: 3106714
#     best_jaccard: 0.0851063829787234
#     best_jaccard_subtree_size: 23
#     alpha: 0.75
#     alpha_node: 1239
#     alpha_fraction: 0.9642857142857143
#     alpha_subtree_size: 94865
#     alpha_outliers: 1
#
# Cluster 47/48
#   in_tree=11  skipped=0
#   Majority α=0.75: 2 [Bacteria]  frac=1.000  size=594260
#   Best coverage: 2 [Bacteria]  frac=1.000  size=594260
#   Best Jaccard: 511051 [Caldisericum exile AZM16c01]  J=0.091  size=1
#   Representative clade: 2 [Bacteria]
#   Core=11  Outliers=0
#     n_in_cluster: 11
#     n_skipped: 0
#     best_coverage_node: 2
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 594260
#     best_jaccard_node: 511051
#     best_jaccard: 0.09090909090909091
#     best_jaccard_subtree_size: 1
#     alpha: 0.75
#     alpha_node: 2
#     alpha_fraction: 1.0
#     alpha_subtree_size: 594260
#     alpha_outliers: 0
#
# Cluster 48/48
#   in_tree=54  skipped=0
#   Majority α=0.75: 1224 [Pseudomonadota]  frac=0.963  size=241984
#   Best coverage: 3379134 [Pseudomonadati]  frac=1.000  size=290974
#   Best Jaccard: 138073 [Candidatus Regiella insecticola]  J=0.036  size=3
#   Representative clade: 1224 [Pseudomonadota]
#   Core=52  Outliers=2
#     n_in_cluster: 54
#     n_skipped: 0
#     best_coverage_node: 3379134
#     best_coverage_fraction: 1.0
#     best_coverage_subtree_size: 290974
#     best_jaccard_node: 138073
#     best_jaccard: 0.03636363636363636
#     best_jaccard_subtree_size: 3
#     alpha: 0.75
#     alpha_node: 1224
#     alpha_fraction: 0.9629629629629629
#     alpha_subtree_size: 241984
#     alpha_outliers: 2

# %%
def cluster_separation(idx, reps):
    """
    Compute how distinct clusters' representative clades are on the tree.

    Returns:
      - overlap_matrix[i,j] = True if subtrees overlap (nested or intersect)
      - distance_matrix[i,j] = edge distance between representative nodes
      - separation_fraction = fraction of cluster pairs that are disjoint
      - mean_interclade_distance = mean distance across distinct clades
    """
    tin, tout, depth, parent = idx["tin"], idx["tout"], idx["depth"], idx["parent"]
    n = len(reps)
    overlap = np.zeros((n, n), dtype=bool)
    dist = np.zeros((n, n), dtype=float)

    # helper to find LCA distance
    def lca_distance(u, v):
        if u is None or v is None:
            return np.nan
        a, b = u, v
        while not (tin[a] <= tin[b] <= tout[a]) and not (tin[b] <= tin[a] <= tout[b]):
            if depth[a] > depth[b]:
                a = parent[a]
            else:
                b = parent[b]
        lca = a if tin[a] <= tin[b] <= tout[a] else b
        return depth[u] + depth[v] - 2 * depth[lca]

    for i in range(n):
        a = reps[i]
        if a is None:
            continue
        for j in range(i + 1, n):
            b = reps[j]
            if b is None:
                continue
            # overlap test
            if (tin[a] <= tin[b] <= tout[a]) or (tin[b] <= tin[a] <= tout[b]):
                overlap[i, j] = overlap[j, i] = True
            # distance
            dist[i, j] = dist[j, i] = lca_distance(a, b)

    # fraction of disjoint (non-overlapping) pairs
    nonoverlap_fraction = 1 - overlap[np.triu_indices(n, 1)].mean()
    # mean interclade distance ignoring NaN
    mean_dist = np.nanmean(dist[np.triu_indices(n, 1)])
    return {
        "overlap_matrix": overlap,
        "distance_matrix": dist,
        "fraction_disjoint": nonoverlap_fraction,
        "mean_interclade_distance": mean_dist,
    }

# %%
def summarize_separation(idx, clusters, tid2nm, alpha=0.65):
    """Print global separation stats and a compact matrix of overlaps."""
    reps = []
    for C in clusters:
        stats = cluster_tree_stats(idx, C, alpha=alpha)
        reps.append(stats.get("alpha_node") or stats.get("best_jaccard_node"))

    sep = cluster_separation(idx, reps)
    print(f"\nGlobal cluster separation:")
    print(f"  Fraction of disjoint clades: {sep['fraction_disjoint']:.3f}")
    print(f"  Mean interclade distance: {sep['mean_interclade_distance']:.2f}\n")

    # show which clusters overlap
    n = len(reps)
    print("Pairwise overlap (Y=overlap, .=disjoint):")
    for i in range(n):
        row = ''.join('Y' if sep["overlap_matrix"][i,j] else '.' for j in range(n))
        print(f"Cluster {i+1:>2}: {row}")
        
summarize_separation(idx, clusters.values(), tid2nm, alpha=0.65)
# Out:
# Global cluster separation:
#   Fraction of disjoint clades: 0.673
#   Mean interclade distance: 4.67
#
# Pairwise overlap (Y=overlap, .=disjoint):
# Cluster  1: .Y..Y.Y.YY.YYY..Y.YY.YYY.YYYYY.YYY..YYY...YY..YY
# Cluster  2: Y.......Y..YY.....Y.......Y.Y..Y....Y.Y.......YY
# Cluster  3: ........Y.Y...................Y...Y.Y.YY....YYY.
# Cluster  4: ........Y...........Y...............Y.Y.....Y.Y.
# Cluster  5: Y.......Y.......Y.Y.......Y.Y.......Y.Y.......Y.
# Cluster  6: .......YY......Y...................YY.Y.....Y.Y.
# Cluster  7: Y.......YY.YYY....Y.......Y.Y....Y..Y.Y...Y...YY
# Cluster  8: .....Y..Y......Y...................YY.Y.....Y.Y.
# Cluster  9: YYYYYYYY.YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY
# Cluster 10: Y.....Y.Y..YYY....Y.......Y.Y....Y..Y.Y...Y...YY
# Cluster 11: ..Y.....Y.....................Y...Y.Y.YY....YYY.
# Cluster 12: YY....Y.YY..YY....YY..Y..YY.Y..Y.Y..YYY...Y...YY
# Cluster 13: YY....Y.YY.Y.Y....YY..Y..YY.Y..Y.Y..YYY...Y...YY
# Cluster 14: Y.....Y.YY.YY.....Y.......Y.Y....Y..Y.Y...Y...YY
# Cluster 15: ........Y........Y..................Y.Y.....YYY.
# Cluster 16: .....Y.YY..........................YY.Y.....Y.Y.
# Cluster 17: Y...Y...Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 18: ........Y.....Y.....................Y.Y.....YYY.
# Cluster 19: YY..Y.Y.YY.YYY..Y..Y.YYY.YYYYY.YYY..YYY...YY..YY
# Cluster 20: Y.......Y..YY.....Y......YY.Y.......Y.Y.......YY
# Cluster 21: ...Y....Y...........................Y.Y.....Y.Y.
# Cluster 22: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 23: Y.......Y..YY.....Y.......Y.Y..Y....Y.Y.......YY
# Cluster 24: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 25: ........Y...........................Y.Y.....Y.Y.
# Cluster 26: Y.......Y..YY.....YY......Y.Y.......Y.Y.......YY
# Cluster 27: YY..Y.Y.YY.YYY..Y.YY.YYY.Y.YYY.YYY..YYY...YY..YY
# Cluster 28: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 29: YY..Y.Y.YY.YYY..Y.YY.YYY.YYY.Y.YYY..YYY...YY..YY
# Cluster 30: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 31: ..Y.....Y.Y.......................Y.Y.YY....YYY.
# Cluster 32: YY......Y..YY.....Y...Y...Y.Y.......YYY.......YY
# Cluster 33: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 34: Y.....Y.YY.YYY....Y.......Y.Y.......Y.Y.......YY
# Cluster 35: ..Y.....Y.Y...................Y.....Y.YY....YYY.
# Cluster 36: .....Y.YY......Y....................Y.Y.....Y.Y.
# Cluster 37: YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY.YYYYYYYYYYY
# Cluster 38: Y.......Y..YY.....Y.......Y.Y..Y....Y.Y.......YY
# Cluster 39: YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY.YYYYYYYYY
# Cluster 40: ..Y.....Y.Y...................Y...Y.Y.Y.....YYY.
# Cluster 41: ........Y...........................Y.Y.....Y.Y.
# Cluster 42: ........Y...........................Y.Y.....YYY.
# Cluster 43: Y.....Y.YY.YYY....Y.......Y.Y.......Y.Y.......YY
# Cluster 44: Y.......Y.........Y.......Y.Y.......Y.Y.......Y.
# Cluster 45: ..YY.Y.YY.Y...YY.Y..Y...Y.....Y...YYY.YYYY...YY.
# Cluster 46: ..Y.....Y.Y...Y..Y............Y...Y.Y.YY.Y..Y.Y.
# Cluster 47: YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY.Y
# Cluster 48: YY....Y.YY.YYY....YY..Y..YY.Y..Y.Y..YYY...Y...Y.
